# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import*
import random
#================================== End of importing required packages and libraries ==========================================#
# Out:
# 2025-02-06 22:30:29.307482: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-06 22:30:29.333855: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-06 22:30:29.725332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'NON_IID'
ALPHA = 1
NUM_PEERS = 100 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)


CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 200 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda:0"
else:
    DEVICE = "cpu"
print(DEVICE)
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1
ATTACK_PERCENTAGE = [0.4]
# Out:
# cuda:0

# %%
# Attack with no defense
RULE = 'localEval'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in ATTACK_PERCENTAGE:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
#
# --> Starting experiment...
# The function distribute_dataset is from the module sampling.
# -->  Loading of MNIST dataset
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: NON_IID
# Aggregation rule: localEval
# Attack Type: label_flipping
# Attackers Ratio: 40.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#
# Directory stats/NON_IID/MNIST/localEval/0.4 created
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Average test loss: 2.2252, Test accuracy: 2554/10000 (25.54%)
#
# Class      - Accuracy
# Zero       - 4.3
# One        - 5.1
# Two        - 23.0
# Three      - 64.3
# Four       - 0.7
# Five       - 0.6
# Six        - 0.4
# Seven      - 87.4
# Eight      - 0.0
# Nine       - 64.8
#
#  | Global training round : 2/200 |
#
#
# Average test loss: 1.9602, Test accuracy: 4692/10000 (46.92%)
#
# Class      - Accuracy
# Zero       - 71.1
# One        - 92.9
# Two        - 35.5
# Three      - 81.8
# Four       - 9.2
# Five       - 16.3
# Six        - 8.5
# Seven      - 88.7
# Eight      - 23.0
# Nine       - 29.4
#
#  | Global training round : 3/200 |
#
#
# Average test loss: 1.4723, Test accuracy: 6440/10000 (64.40%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 93.7
# Two        - 39.9
# Three      - 87.8
# Four       - 51.3
# Five       - 31.1
# Six        - 51.4
# Seven      - 88.4
# Eight      - 26.1
# Nine       - 70.3
#
#  | Global training round : 4/200 |
#
#
# Average test loss: 1.0357, Test accuracy: 8172/10000 (81.72%)
#
# Class      - Accuracy
# Zero       - 96.2
# One        - 94.7
# Two        - 81.7
# Three      - 87.8
# Four       - 78.8
# Five       - 58.5
# Six        - 85.3
# Seven      - 86.9
# Eight      - 54.3
# Nine       - 88.1
#
#  | Global training round : 5/200 |
#
#
# Average test loss: 0.6415, Test accuracy: 8773/10000 (87.73%)
#
# Class      - Accuracy
# Zero       - 97.3
# One        - 97.0
# Two        - 88.7
# Three      - 90.0
# Four       - 84.2
# Five       - 71.9
# Six        - 93.8
# Seven      - 89.1
# Eight      - 71.4
# Nine       - 90.8
#
#  | Global training round : 6/200 |
#
#
# Average test loss: 0.4121, Test accuracy: 9003/10000 (90.03%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.1
# Two        - 90.0
# Three      - 90.0
# Four       - 90.3
# Five       - 78.9
# Six        - 95.5
# Seven      - 91.0
# Eight      - 75.5
# Nine       - 90.5
#
#  | Global training round : 7/200 |
#
#
# Average test loss: 0.3281, Test accuracy: 9169/10000 (91.69%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.5
# Two        - 91.0
# Three      - 91.4
# Four       - 91.3
# Five       - 84.6
# Six        - 96.5
# Seven      - 91.4
# Eight      - 80.3
# Nine       - 91.8
#
#  | Global training round : 8/200 |
#
#
# Average test loss: 0.2787, Test accuracy: 9255/10000 (92.55%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.7
# Two        - 90.8
# Three      - 92.1
# Four       - 92.8
# Five       - 88.3
# Six        - 96.1
# Seven      - 92.1
# Eight      - 82.9
# Nine       - 92.0
#
#  | Global training round : 9/200 |
#
#
# Average test loss: 0.2482, Test accuracy: 9314/10000 (93.14%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.6
# Two        - 91.6
# Three      - 92.5
# Four       - 93.3
# Five       - 89.3
# Six        - 96.9
# Seven      - 92.3
# Eight      - 84.6
# Nine       - 92.7
#
#  | Global training round : 10/200 |
#
#
# Average test loss: 0.2238, Test accuracy: 9371/10000 (93.71%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.6
# Two        - 91.7
# Three      - 93.9
# Four       - 93.9
# Five       - 90.5
# Six        - 96.9
# Seven      - 93.0
# Eight      - 86.2
# Nine       - 93.0
#
#  | Global training round : 11/200 |
#
#
# Average test loss: 0.2060, Test accuracy: 9409/10000 (94.09%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.7
# Two        - 92.2
# Three      - 93.7
# Four       - 94.4
# Five       - 92.3
# Six        - 97.0
# Seven      - 93.1
# Eight      - 87.2
# Nine       - 93.3
#
#  | Global training round : 12/200 |
#
#
# Average test loss: 0.1939, Test accuracy: 9442/10000 (94.42%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 92.5
# Three      - 93.8
# Four       - 95.0
# Five       - 93.0
# Six        - 97.0
# Seven      - 93.7
# Eight      - 87.5
# Nine       - 93.5
#
#  | Global training round : 13/200 |
#
#
# Average test loss: 0.1815, Test accuracy: 9471/10000 (94.71%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 92.9
# Three      - 94.3
# Four       - 95.2
# Five       - 93.6
# Six        - 96.9
# Seven      - 93.4
# Eight      - 88.7
# Nine       - 94.1
#
#  | Global training round : 14/200 |
#
#
# Average test loss: 0.1711, Test accuracy: 9500/10000 (95.00%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 93.0
# Three      - 94.8
# Four       - 95.1
# Five       - 94.5
# Six        - 96.7
# Seven      - 94.1
# Eight      - 89.4
# Nine       - 94.4
#
#  | Global training round : 15/200 |
#
#
# Average test loss: 0.1638, Test accuracy: 9518/10000 (95.18%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 93.5
# Three      - 94.9
# Four       - 94.9
# Five       - 94.6
# Six        - 97.3
# Seven      - 94.2
# Eight      - 90.0
# Nine       - 94.8
#
#  | Global training round : 16/200 |
#
#
# Average test loss: 0.1566, Test accuracy: 9534/10000 (95.34%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 93.8
# Three      - 95.4
# Four       - 95.3
# Five       - 94.3
# Six        - 97.2
# Seven      - 94.3
# Eight      - 90.3
# Nine       - 94.6
#
#  | Global training round : 17/200 |
#
#
# Average test loss: 0.1490, Test accuracy: 9558/10000 (95.58%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 94.5
# Three      - 95.5
# Four       - 95.7
# Five       - 95.3
# Six        - 97.1
# Seven      - 94.3
# Eight      - 90.8
# Nine       - 94.6
#
#  | Global training round : 18/200 |
#
#
# Average test loss: 0.1437, Test accuracy: 9573/10000 (95.73%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 95.1
# Three      - 95.5
# Four       - 95.7
# Five       - 95.1
# Six        - 97.3
# Seven      - 94.2
# Eight      - 91.3
# Nine       - 94.9
#
#  | Global training round : 19/200 |
#
#
# Average test loss: 0.1384, Test accuracy: 9582/10000 (95.82%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.2
# Three      - 95.4
# Four       - 95.8
# Five       - 95.7
# Six        - 97.5
# Seven      - 94.2
# Eight      - 91.6
# Nine       - 94.9
#
#  | Global training round : 20/200 |
#
#
# Average test loss: 0.1344, Test accuracy: 9594/10000 (95.94%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.4
# Three      - 96.1
# Four       - 95.8
# Five       - 96.1
# Six        - 97.4
# Seven      - 94.2
# Eight      - 91.6
# Nine       - 94.9
#
#  | Global training round : 21/200 |
#
#
# Average test loss: 0.1298, Test accuracy: 9610/10000 (96.10%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 95.4
# Three      - 95.9
# Four       - 95.9
# Five       - 96.3
# Six        - 97.5
# Seven      - 94.6
# Eight      - 91.9
# Nine       - 95.0
#
#  | Global training round : 22/200 |
#
#
# Average test loss: 0.1258, Test accuracy: 9621/10000 (96.21%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 95.7
# Three      - 96.4
# Four       - 95.9
# Five       - 96.4
# Six        - 97.6
# Seven      - 94.6
# Eight      - 92.0
# Nine       - 95.3
#
#  | Global training round : 23/200 |
#
#
# Average test loss: 0.1222, Test accuracy: 9629/10000 (96.29%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 95.7
# Three      - 96.4
# Four       - 96.0
# Five       - 96.6
# Six        - 97.6
# Seven      - 95.0
# Eight      - 92.1
# Nine       - 95.1
#
#  | Global training round : 24/200 |
#
#
# Average test loss: 0.1194, Test accuracy: 9627/10000 (96.27%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 95.7
# Three      - 96.4
# Four       - 95.8
# Five       - 96.7
# Six        - 97.6
# Seven      - 94.8
# Eight      - 92.0
# Nine       - 95.4
#
#  | Global training round : 25/200 |
#
#
# Average test loss: 0.1160, Test accuracy: 9635/10000 (96.35%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 95.8
# Three      - 96.0
# Four       - 96.2
# Five       - 96.6
# Six        - 97.6
# Seven      - 94.8
# Eight      - 92.5
# Nine       - 95.6
#
#  | Global training round : 26/200 |
#
#
# Average test loss: 0.1128, Test accuracy: 9649/10000 (96.49%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 96.1
# Three      - 96.7
# Four       - 96.3
# Five       - 96.7
# Six        - 97.5
# Seven      - 95.1
# Eight      - 92.4
# Nine       - 95.6
#
#  | Global training round : 27/200 |
#
#
# Average test loss: 0.1117, Test accuracy: 9656/10000 (96.56%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 96.0
# Three      - 96.8
# Four       - 96.7
# Five       - 97.1
# Six        - 97.6
# Seven      - 94.8
# Eight      - 92.5
# Nine       - 95.7
#
#  | Global training round : 28/200 |
#
#
# Average test loss: 0.1084, Test accuracy: 9661/10000 (96.61%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 96.2
# Three      - 96.7
# Four       - 96.2
# Five       - 97.4
# Six        - 97.6
# Seven      - 95.1
# Eight      - 92.8
# Nine       - 95.7
#
#  | Global training round : 29/200 |
#
#
# Average test loss: 0.1075, Test accuracy: 9670/10000 (96.70%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.1
# Three      - 96.9
# Four       - 96.6
# Five       - 97.2
# Six        - 97.6
# Seven      - 95.4
# Eight      - 93.0
# Nine       - 95.6
#
#  | Global training round : 30/200 |
#
#
# Average test loss: 0.1048, Test accuracy: 9669/10000 (96.69%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.3
# Three      - 96.9
# Four       - 96.1
# Five       - 97.1
# Six        - 97.4
# Seven      - 95.1
# Eight      - 93.6
# Nine       - 95.9
#
#  | Global training round : 31/200 |
#
#
# Average test loss: 0.1022, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 96.3
# Three      - 96.9
# Four       - 96.9
# Five       - 97.5
# Six        - 97.4
# Seven      - 95.7
# Eight      - 93.6
# Nine       - 95.8
#
#  | Global training round : 32/200 |
#
#
# Average test loss: 0.1017, Test accuracy: 9688/10000 (96.88%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 96.4
# Three      - 96.8
# Four       - 96.5
# Five       - 97.5
# Six        - 97.7
# Seven      - 95.8
# Eight      - 93.5
# Nine       - 96.0
#
#  | Global training round : 33/200 |
#
#
# Average test loss: 0.0992, Test accuracy: 9689/10000 (96.89%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 96.5
# Three      - 97.0
# Four       - 96.2
# Five       - 97.3
# Six        - 97.5
# Seven      - 95.7
# Eight      - 94.0
# Nine       - 96.0
#
#  | Global training round : 34/200 |
#
#
# Average test loss: 0.0983, Test accuracy: 9689/10000 (96.89%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.5
# Three      - 97.1
# Four       - 96.2
# Five       - 97.4
# Six        - 97.6
# Seven      - 95.8
# Eight      - 93.9
# Nine       - 95.9
#
#  | Global training round : 35/200 |
#
#
# Average test loss: 0.0956, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 96.4
# Three      - 97.2
# Four       - 96.8
# Five       - 98.0
# Six        - 97.6
# Seven      - 95.8
# Eight      - 93.9
# Nine       - 96.2
#
#  | Global training round : 36/200 |
#
#
# Average test loss: 0.0947, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 96.4
# Three      - 97.0
# Four       - 96.8
# Five       - 97.5
# Six        - 98.0
# Seven      - 95.8
# Eight      - 94.6
# Nine       - 96.2
#
#  | Global training round : 37/200 |
#
#
# Average test loss: 0.0934, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 96.7
# Three      - 97.3
# Four       - 96.7
# Five       - 98.0
# Six        - 97.7
# Seven      - 95.7
# Eight      - 94.3
# Nine       - 96.1
#
#  | Global training round : 38/200 |
#
#
# Average test loss: 0.0916, Test accuracy: 9715/10000 (97.15%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.8
# Three      - 97.0
# Four       - 96.8
# Five       - 98.0
# Six        - 97.7
# Seven      - 95.8
# Eight      - 94.9
# Nine       - 96.1
#
#  | Global training round : 39/200 |
#
#
# Average test loss: 0.0918, Test accuracy: 9717/10000 (97.17%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 96.8
# Three      - 97.3
# Four       - 96.7
# Five       - 98.1
# Six        - 97.8
# Seven      - 96.0
# Eight      - 94.5
# Nine       - 96.0
#
#  | Global training round : 40/200 |
#
#
# Average test loss: 0.0900, Test accuracy: 9723/10000 (97.23%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.8
# Three      - 97.4
# Four       - 96.9
# Five       - 98.0
# Six        - 97.9
# Seven      - 95.9
# Eight      - 94.9
# Nine       - 96.1
#
#  | Global training round : 41/200 |
#
#
# Average test loss: 0.0886, Test accuracy: 9720/10000 (97.20%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.9
# Three      - 97.0
# Four       - 96.7
# Five       - 98.1
# Six        - 98.0
# Seven      - 95.7
# Eight      - 95.1
# Nine       - 96.1
#
#  | Global training round : 42/200 |
#
#
# Average test loss: 0.0886, Test accuracy: 9721/10000 (97.21%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.7
# Three      - 97.6
# Four       - 96.7
# Five       - 98.1
# Six        - 98.1
# Seven      - 96.0
# Eight      - 94.4
# Nine       - 96.1
#
#  | Global training round : 43/200 |
#
#
# Average test loss: 0.0862, Test accuracy: 9726/10000 (97.26%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.8
# Three      - 97.2
# Four       - 96.9
# Five       - 98.2
# Six        - 98.1
# Seven      - 96.0
# Eight      - 94.9
# Nine       - 96.1
#
#  | Global training round : 44/200 |
#
#
# Average test loss: 0.0857, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.8
# Three      - 97.8
# Four       - 96.8
# Five       - 98.2
# Six        - 98.0
# Seven      - 95.9
# Eight      - 94.9
# Nine       - 96.1
#
#  | Global training round : 45/200 |
#
#
# Average test loss: 0.0849, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 96.9
# Three      - 97.6
# Four       - 96.8
# Five       - 98.2
# Six        - 97.7
# Seven      - 95.8
# Eight      - 95.0
# Nine       - 96.4
#
#  | Global training round : 46/200 |
#
#
# Average test loss: 0.0830, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 96.8
# Three      - 97.6
# Four       - 96.7
# Five       - 98.3
# Six        - 97.8
# Seven      - 96.0
# Eight      - 95.2
# Nine       - 96.3
#
#  | Global training round : 47/200 |
#
#
# Average test loss: 0.0826, Test accuracy: 9733/10000 (97.33%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.1
# Three      - 97.5
# Four       - 97.0
# Five       - 98.2
# Six        - 97.8
# Seven      - 96.0
# Eight      - 94.9
# Nine       - 96.3
#
#  | Global training round : 48/200 |
#
#
# Average test loss: 0.0827, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.0
# Three      - 97.6
# Four       - 96.7
# Five       - 98.4
# Six        - 98.0
# Seven      - 96.2
# Eight      - 95.1
# Nine       - 96.5
#
#  | Global training round : 49/200 |
#
#
# Average test loss: 0.0809, Test accuracy: 9740/10000 (97.40%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.2
# Three      - 97.7
# Four       - 96.9
# Five       - 98.4
# Six        - 97.9
# Seven      - 96.2
# Eight      - 95.0
# Nine       - 96.4
#
#  | Global training round : 50/200 |
#
#
# Average test loss: 0.0803, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.0
# Three      - 97.6
# Four       - 97.0
# Five       - 98.3
# Six        - 98.0
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.5
#
#  | Global training round : 51/200 |
#
#
# Average test loss: 0.0800, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.2
# Three      - 97.6
# Four       - 96.7
# Five       - 98.4
# Six        - 98.0
# Seven      - 96.1
# Eight      - 95.5
# Nine       - 96.6
#
#  | Global training round : 52/200 |
#
#
# Average test loss: 0.0788, Test accuracy: 9747/10000 (97.47%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.1
# Three      - 97.6
# Four       - 97.0
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.5
#
#  | Global training round : 53/200 |
#
#
# Average test loss: 0.0786, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.2
# Three      - 97.6
# Four       - 97.0
# Five       - 98.2
# Six        - 98.1
# Seven      - 96.2
# Eight      - 95.1
# Nine       - 96.5
#
#  | Global training round : 54/200 |
#
#
# Average test loss: 0.0778, Test accuracy: 9752/10000 (97.52%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.2
# Three      - 97.8
# Four       - 97.0
# Five       - 98.2
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.4
# Nine       - 96.6
#
#  | Global training round : 55/200 |
#
#
# Average test loss: 0.0763, Test accuracy: 9755/10000 (97.55%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.2
# Three      - 97.9
# Four       - 96.8
# Five       - 98.5
# Six        - 98.1
# Seven      - 96.3
# Eight      - 95.6
# Nine       - 96.7
#
#  | Global training round : 56/200 |
#
#
# Average test loss: 0.0767, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.3
# Three      - 97.8
# Four       - 96.8
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.5
# Nine       - 96.6
#
#  | Global training round : 57/200 |
#
#
# Average test loss: 0.0759, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.1
# Three      - 97.7
# Four       - 96.9
# Five       - 98.3
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.8
# Nine       - 96.6
#
#  | Global training round : 58/200 |
#
#
# Average test loss: 0.0753, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.2
# Three      - 97.6
# Four       - 96.8
# Five       - 98.2
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.9
# Nine       - 96.7
#
#  | Global training round : 59/200 |
#
#
# Average test loss: 0.0747, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.3
# Three      - 97.8
# Four       - 97.1
# Five       - 98.5
# Six        - 98.2
# Seven      - 96.4
# Eight      - 95.9
# Nine       - 96.7
#
#  | Global training round : 60/200 |
#
#
# Average test loss: 0.0737, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.4
# Three      - 97.8
# Four       - 97.0
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.4
# Eight      - 96.1
# Nine       - 96.7
#
#  | Global training round : 61/200 |
#
#
# Average test loss: 0.0733, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.5
# Three      - 98.0
# Four       - 96.9
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.3
# Eight      - 96.2
# Nine       - 96.7
#
#  | Global training round : 62/200 |
#
#
# Average test loss: 0.0731, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.4
# Three      - 97.9
# Four       - 97.0
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.4
# Eight      - 95.9
# Nine       - 97.0
#
#  | Global training round : 63/200 |
#
#
# Average test loss: 0.0722, Test accuracy: 9769/10000 (97.69%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.2
# Three      - 97.9
# Four       - 97.0
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.4
# Eight      - 96.2
# Nine       - 96.8
#
#  | Global training round : 64/200 |
#
#
# Average test loss: 0.0724, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 97.6
# Three      - 97.9
# Four       - 97.1
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.7
# Nine       - 96.8
#
#  | Global training round : 65/200 |
#
#
# Average test loss: 0.0714, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.5
# Three      - 97.9
# Four       - 97.0
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.2
# Eight      - 96.1
# Nine       - 96.7
#
#  | Global training round : 66/200 |
#
#
# Average test loss: 0.0710, Test accuracy: 9771/10000 (97.71%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.7
# Three      - 97.9
# Four       - 97.0
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.4
# Eight      - 96.0
# Nine       - 96.7
#
#  | Global training round : 67/200 |
#
#
# Average test loss: 0.0698, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.7
# Three      - 97.9
# Four       - 97.4
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.3
# Eight      - 96.2
# Nine       - 96.7
#
#  | Global training round : 68/200 |
#
#
# Average test loss: 0.0700, Test accuracy: 9773/10000 (97.73%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.7
# Three      - 98.1
# Four       - 97.1
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.5
# Eight      - 95.9
# Nine       - 96.7
#
#  | Global training round : 69/200 |
#
#
# Average test loss: 0.0701, Test accuracy: 9773/10000 (97.73%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.8
# Three      - 97.9
# Four       - 97.1
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.3
# Eight      - 96.1
# Nine       - 96.7
#
#  | Global training round : 70/200 |
#
#
# Average test loss: 0.0684, Test accuracy: 9779/10000 (97.79%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 97.7
# Three      - 98.0
# Four       - 97.4
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.4
# Eight      - 96.1
# Nine       - 96.7
#
#  | Global training round : 71/200 |
#
#
# Average test loss: 0.0683, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.8
# Three      - 98.0
# Four       - 97.5
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.4
# Eight      - 96.3
# Nine       - 96.9
#
#  | Global training round : 72/200 |
#
#
# Average test loss: 0.0678, Test accuracy: 9785/10000 (97.85%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.9
# Three      - 98.1
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.5
# Eight      - 96.2
# Nine       - 96.9
#
#  | Global training round : 73/200 |
#
#
# Average test loss: 0.0676, Test accuracy: 9781/10000 (97.81%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.8
# Three      - 98.0
# Four       - 97.3
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.5
# Eight      - 96.2
# Nine       - 96.8
#
#  | Global training round : 74/200 |
#
#
# Average test loss: 0.0672, Test accuracy: 9788/10000 (97.88%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.9
# Three      - 98.0
# Four       - 97.4
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.1
# Nine       - 97.0
#
#  | Global training round : 75/200 |
#
#
# Average test loss: 0.0670, Test accuracy: 9789/10000 (97.89%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 97.5
# Five       - 98.5
# Six        - 98.4
# Seven      - 96.4
# Eight      - 96.3
# Nine       - 97.0
#
#  | Global training round : 76/200 |
#
#
# Average test loss: 0.0661, Test accuracy: 9790/10000 (97.90%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.9
# Three      - 98.0
# Four       - 97.7
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.1
# Nine       - 96.9
#
#  | Global training round : 77/200 |
#
#
# Average test loss: 0.0665, Test accuracy: 9785/10000 (97.85%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.7
# Three      - 97.9
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.1
# Nine       - 96.8
#
#  | Global training round : 78/200 |
#
#
# Average test loss: 0.0658, Test accuracy: 9789/10000 (97.89%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.9
# Three      - 98.0
# Four       - 97.3
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.1
# Nine       - 97.1
#
#  | Global training round : 79/200 |
#
#
# Average test loss: 0.0656, Test accuracy: 9788/10000 (97.88%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.3
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.6
# Eight      - 96.3
# Nine       - 96.9
#
#  | Global training round : 80/200 |
#
#
# Average test loss: 0.0649, Test accuracy: 9795/10000 (97.95%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.8
# Three      - 98.0
# Four       - 97.9
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.0
#
#  | Global training round : 81/200 |
#
#
# Average test loss: 0.0643, Test accuracy: 9795/10000 (97.95%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 97.6
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.8
# Eight      - 96.5
# Nine       - 96.8
#
#  | Global training round : 82/200 |
#
#
# Average test loss: 0.0650, Test accuracy: 9791/10000 (97.91%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.3
# Five       - 98.7
# Six        - 98.4
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.1
#
#  | Global training round : 83/200 |
#
#
# Average test loss: 0.0644, Test accuracy: 9794/10000 (97.94%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.4
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.3
# Nine       - 97.3
#
#  | Global training round : 84/200 |
#
#
# Average test loss: 0.0639, Test accuracy: 9794/10000 (97.94%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.4
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.6
# Eight      - 96.5
# Nine       - 97.2
#
#  | Global training round : 85/200 |
#
#
# Average test loss: 0.0637, Test accuracy: 9795/10000 (97.95%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.8
# Five       - 98.7
# Six        - 98.4
# Seven      - 96.7
# Eight      - 96.4
# Nine       - 97.0
#
#  | Global training round : 86/200 |
#
#
# Average test loss: 0.0632, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.8
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.2
# Nine       - 97.0
#
#  | Global training round : 87/200 |
#
#
# Average test loss: 0.0633, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 97.9
# Four       - 97.7
# Five       - 98.5
# Six        - 98.4
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.0
#
#  | Global training round : 88/200 |
#
#
# Average test loss: 0.0625, Test accuracy: 9798/10000 (97.98%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.9
# Three      - 98.1
# Four       - 97.8
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.4
# Nine       - 97.2
#
#  | Global training round : 89/200 |
#
#
# Average test loss: 0.0624, Test accuracy: 9794/10000 (97.94%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.1
# Four       - 97.4
# Five       - 98.7
# Six        - 98.4
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.2
#
#  | Global training round : 90/200 |
#
#
# Average test loss: 0.0619, Test accuracy: 9796/10000 (97.96%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 98.0
# Four       - 97.9
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.6
# Eight      - 96.4
# Nine       - 97.1
#
#  | Global training round : 91/200 |
#
#
# Average test loss: 0.0614, Test accuracy: 9800/10000 (98.00%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 98.1
# Four       - 97.5
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.5
# Nine       - 97.3
#
#  | Global training round : 92/200 |
#
#
# Average test loss: 0.0616, Test accuracy: 9800/10000 (98.00%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.1
# Three      - 98.1
# Four       - 97.9
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.4
# Nine       - 97.0
#
#  | Global training round : 93/200 |
#
#
# Average test loss: 0.0609, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.9
# Three      - 97.9
# Four       - 97.8
# Five       - 98.8
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.4
# Nine       - 97.4
#
#  | Global training round : 94/200 |
#
#
# Average test loss: 0.0606, Test accuracy: 9799/10000 (97.99%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 98.0
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.3
# Nine       - 97.1
#
#  | Global training round : 95/200 |
#
#
# Average test loss: 0.0604, Test accuracy: 9806/10000 (98.06%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.1
# Three      - 98.0
# Four       - 98.1
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.6
# Nine       - 97.2
#
#  | Global training round : 96/200 |
#
#
# Average test loss: 0.0601, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.1
# Three      - 98.0
# Four       - 97.6
# Five       - 98.7
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.6
# Nine       - 97.2
#
#  | Global training round : 97/200 |
#
#
# Average test loss: 0.0604, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 97.8
# Five       - 98.5
# Six        - 98.4
# Seven      - 96.9
# Eight      - 96.6
# Nine       - 97.2
#
#  | Global training round : 98/200 |
#
#
# Average test loss: 0.0599, Test accuracy: 9804/10000 (98.04%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.9
# Three      - 98.1
# Four       - 97.9
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.9
# Eight      - 96.6
# Nine       - 97.1
#
#  | Global training round : 99/200 |
#
#
# Average test loss: 0.0603, Test accuracy: 9806/10000 (98.06%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 98.0
# Three      - 98.2
# Four       - 97.9
# Five       - 98.8
# Six        - 98.4
# Seven      - 97.0
# Eight      - 96.4
# Nine       - 97.2
#
#  | Global training round : 100/200 |
#
#
# Average test loss: 0.0597, Test accuracy: 9809/10000 (98.09%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.0
# Four       - 97.8
# Five       - 98.8
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.8
# Nine       - 97.2
#
#  | Global training round : 101/200 |
#
#
# Average test loss: 0.0594, Test accuracy: 9808/10000 (98.08%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.1
# Four       - 97.9
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.9
# Eight      - 96.4
# Nine       - 97.3
#
#  | Global training round : 102/200 |
#
#
# Average test loss: 0.0590, Test accuracy: 9806/10000 (98.06%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 98.0
# Three      - 98.1
# Four       - 97.7
# Five       - 98.7
# Six        - 98.4
# Seven      - 97.0
# Eight      - 96.7
# Nine       - 97.3
#
#  | Global training round : 103/200 |
#
#
# Average test loss: 0.0585, Test accuracy: 9808/10000 (98.08%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.1
# Three      - 98.1
# Four       - 97.6
# Five       - 98.8
# Six        - 98.4
# Seven      - 96.9
# Eight      - 96.7
# Nine       - 97.4
#
#  | Global training round : 104/200 |
#
#
# Average test loss: 0.0584, Test accuracy: 9811/10000 (98.11%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.0
# Three      - 98.0
# Four       - 97.8
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.0
# Eight      - 96.6
# Nine       - 97.4
#
#  | Global training round : 105/200 |
#
#
# Average test loss: 0.0587, Test accuracy: 9810/10000 (98.10%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.3
# Three      - 98.1
# Four       - 97.9
# Five       - 98.7
# Six        - 98.4
# Seven      - 97.0
# Eight      - 96.5
# Nine       - 97.3
#
#  | Global training round : 106/200 |
#
#
# Average test loss: 0.0584, Test accuracy: 9812/10000 (98.12%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.1
# Three      - 98.2
# Four       - 97.7
# Five       - 98.8
# Six        - 98.4
# Seven      - 97.1
# Eight      - 96.7
# Nine       - 97.4
#
#  | Global training round : 107/200 |
#
#
# Average test loss: 0.0582, Test accuracy: 9816/10000 (98.16%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.0
# Four       - 97.9
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.1
# Eight      - 96.8
# Nine       - 97.4
#
#  | Global training round : 108/200 |
#
#
# Average test loss: 0.0579, Test accuracy: 9816/10000 (98.16%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.0
# Four       - 98.1
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 97.4
#
#  | Global training round : 109/200 |
#
#
# Average test loss: 0.0569, Test accuracy: 9820/10000 (98.20%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.0
# Four       - 98.5
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.0
# Eight      - 96.9
# Nine       - 97.2
#
#  | Global training round : 110/200 |
#
#
# Average test loss: 0.0570, Test accuracy: 9820/10000 (98.20%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.1
# Four       - 98.2
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.2
# Eight      - 96.9
# Nine       - 97.4
#
#  | Global training round : 111/200 |
#
#
# Average test loss: 0.0568, Test accuracy: 9822/10000 (98.22%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.2
# Four       - 98.1
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.1
# Eight      - 96.9
# Nine       - 97.4
#
#  | Global training round : 112/200 |
#
#
# Average test loss: 0.0570, Test accuracy: 9819/10000 (98.19%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.1
# Four       - 98.1
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.3
# Eight      - 96.8
# Nine       - 97.4
#
#  | Global training round : 113/200 |
#
#
# Average test loss: 0.0570, Test accuracy: 9819/10000 (98.19%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.2
# Four       - 98.1
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.4
# Eight      - 96.7
# Nine       - 97.3
#
#  | Global training round : 114/200 |
#
#
# Average test loss: 0.0561, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.3
# Three      - 98.0
# Four       - 98.3
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.3
#
#  | Global training round : 115/200 |
#
#
# Average test loss: 0.0557, Test accuracy: 9828/10000 (98.28%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.1
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.1
# Eight      - 97.3
# Nine       - 97.6
#
#  | Global training round : 116/200 |
#
#
# Average test loss: 0.0562, Test accuracy: 9821/10000 (98.21%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.2
# Three      - 98.2
# Four       - 98.1
# Five       - 98.7
# Six        - 98.4
# Seven      - 97.4
# Eight      - 96.9
# Nine       - 97.4
#
#  | Global training round : 117/200 |
#
#
# Average test loss: 0.0555, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.0
# Four       - 98.1
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 118/200 |
#
#
# Average test loss: 0.0560, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.1
# Four       - 98.2
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.2
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 119/200 |
#
#
# Average test loss: 0.0554, Test accuracy: 9828/10000 (98.28%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.1
# Four       - 98.2
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 120/200 |
#
#
# Average test loss: 0.0552, Test accuracy: 9826/10000 (98.26%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.1
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.4
# Eight      - 96.9
# Nine       - 97.5
#
#  | Global training round : 121/200 |
#
#
# Average test loss: 0.0545, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.2
# Four       - 98.1
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 122/200 |
#
#
# Average test loss: 0.0543, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.3
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 123/200 |
#
#
# Average test loss: 0.0544, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 98.2
# Three      - 98.0
# Four       - 98.5
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.3
#
#  | Global training round : 124/200 |
#
#
# Average test loss: 0.0536, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.2
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 125/200 |
#
#
# Average test loss: 0.0541, Test accuracy: 9831/10000 (98.31%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.2
# Four       - 98.5
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.3
# Nine       - 97.5
#
#  | Global training round : 126/200 |
#
#
# Average test loss: 0.0542, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.6
#
#  | Global training round : 127/200 |
#
#
# Average test loss: 0.0533, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.3
# Three      - 98.3
# Four       - 98.3
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 128/200 |
#
#
# Average test loss: 0.0537, Test accuracy: 9826/10000 (98.26%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.2
# Four       - 98.2
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.2
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 129/200 |
#
#
# Average test loss: 0.0538, Test accuracy: 9829/10000 (98.29%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.1
# Four       - 98.5
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 130/200 |
#
#
# Average test loss: 0.0543, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.2
# Four       - 98.4
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 131/200 |
#
#
# Average test loss: 0.0539, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.5
# Five       - 98.7
# Six        - 98.9
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.4
#
#  | Global training round : 132/200 |
#
#
# Average test loss: 0.0536, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.2
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 133/200 |
#
#
# Average test loss: 0.0533, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.3
# Three      - 98.2
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 134/200 |
#
#
# Average test loss: 0.0533, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.2
# Three      - 98.2
# Four       - 98.2
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 135/200 |
#
#
# Average test loss: 0.0531, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.3
# Three      - 98.3
# Four       - 98.2
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 136/200 |
#
#
# Average test loss: 0.0530, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.6
# Two        - 98.3
# Three      - 98.4
# Four       - 98.2
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.5
# Eight      - 96.9
# Nine       - 97.4
#
#  | Global training round : 137/200 |
#
#
# Average test loss: 0.0523, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.3
# Three      - 98.4
# Four       - 98.2
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 138/200 |
#
#
# Average test loss: 0.0528, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.6
# Two        - 98.3
# Three      - 98.2
# Four       - 98.2
# Five       - 98.8
# Six        - 98.9
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 139/200 |
#
#
# Average test loss: 0.0525, Test accuracy: 9832/10000 (98.32%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.3
# Three      - 98.2
# Four       - 98.4
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.5
# Eight      - 96.9
# Nine       - 97.5
#
#  | Global training round : 140/200 |
#
#
# Average test loss: 0.0518, Test accuracy: 9836/10000 (98.36%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.3
# Three      - 98.2
# Four       - 98.4
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 141/200 |
#
#
# Average test loss: 0.0518, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.6
# Two        - 98.4
# Three      - 98.3
# Four       - 98.7
# Five       - 98.5
# Six        - 98.9
# Seven      - 97.5
# Eight      - 97.0
# Nine       - 97.3
#
#  | Global training round : 142/200 |
#
#
# Average test loss: 0.0518, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.2
# Three      - 98.2
# Four       - 98.6
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.5
# Eight      - 97.3
# Nine       - 97.3
#
#  | Global training round : 143/200 |
#
#
# Average test loss: 0.0512, Test accuracy: 9838/10000 (98.38%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.3
# Three      - 98.3
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.3
# Nine       - 97.3
#
#  | Global training round : 144/200 |
#
#
# Average test loss: 0.0517, Test accuracy: 9834/10000 (98.34%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.2
# Three      - 98.3
# Four       - 98.6
# Five       - 98.4
# Six        - 98.7
# Seven      - 97.4
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 145/200 |
#
#
# Average test loss: 0.0511, Test accuracy: 9839/10000 (98.39%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.2
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.3
#
#  | Global training round : 146/200 |
#
#
# Average test loss: 0.0510, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.3
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.3
# Nine       - 97.7
#
#  | Global training round : 147/200 |
#
#
# Average test loss: 0.0510, Test accuracy: 9836/10000 (98.36%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.2
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 148/200 |
#
#
# Average test loss: 0.0504, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.3
# Three      - 98.3
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 149/200 |
#
#
# Average test loss: 0.0508, Test accuracy: 9837/10000 (98.37%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.4
# Three      - 98.3
# Four       - 98.3
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 150/200 |
#
#
# Average test loss: 0.0506, Test accuracy: 9838/10000 (98.38%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.3
# Nine       - 97.5
#
#  | Global training round : 151/200 |
#
#
# Average test loss: 0.0505, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.4
# Three      - 98.4
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.4
#
#  | Global training round : 152/200 |
#
#
# Average test loss: 0.0505, Test accuracy: 9838/10000 (98.38%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.4
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.4
#
#  | Global training round : 153/200 |
#
#
# Average test loss: 0.0501, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.4
# Three      - 98.4
# Four       - 98.5
# Five       - 98.8
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.6
# Nine       - 97.5
#
#  | Global training round : 154/200 |
#
#
# Average test loss: 0.0507, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.4
# Three      - 98.3
# Four       - 98.5
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.6
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 155/200 |
#
#
# Average test loss: 0.0499, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.4
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 156/200 |
#
#
# Average test loss: 0.0508, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.3
# Three      - 98.5
# ...
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.7
# Nine       - 97.3
#
#  | Global training round : 171/200 |
#
#
# Average test loss: 0.0482, Test accuracy: 9844/10000 (98.44%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.5
# Nine       - 97.4
#
#  | Global training round : 172/200 |
#
#
# Average test loss: 0.0487, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 98.5
# Three      - 98.3
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.4
# Nine       - 97.3
#
#  | Global training round : 173/200 |
#
#
# Average test loss: 0.0479, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.4
# Three      - 98.4
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.6
# Nine       - 97.3
#
#  | Global training round : 174/200 |
#
#
# Average test loss: 0.0477, Test accuracy: 9843/10000 (98.43%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.5
# Nine       - 97.3
#
#  | Global training round : 175/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.8
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.6
# Nine       - 97.4
#
#  | Global training round : 176/200 |
#
#
# Average test loss: 0.0482, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.4
# Nine       - 97.3
#
#  | Global training round : 177/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.5
# Nine       - 97.3
#
#  | Global training round : 178/200 |
#
#
# Average test loss: 0.0483, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.8
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.4
# Nine       - 97.4
#
#  | Global training round : 179/200 |
#
#
# Average test loss: 0.0476, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.5
# Nine       - 97.3
#
#  | Global training round : 180/200 |
#
#
# Average test loss: 0.0473, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.6
# Nine       - 97.3
#
#  | Global training round : 181/200 |
#
#
# Average test loss: 0.0474, Test accuracy: 9844/10000 (98.44%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.4
# Nine       - 97.4
#
#  | Global training round : 182/200 |
#
#
# Average test loss: 0.0476, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 98.5
# Three      - 98.4
# Four       - 98.5
# Five       - 98.8
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.3
# Nine       - 97.3
#
#  | Global training round : 183/200 |
#
#
# Average test loss: 0.0477, Test accuracy: 9844/10000 (98.44%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.3
#
#  | Global training round : 184/200 |
#
#
# Average test loss: 0.0474, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.6
# Nine       - 97.3
#
#  | Global training round : 185/200 |
#
#
# Average test loss: 0.0473, Test accuracy: 9843/10000 (98.43%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.5
# Nine       - 97.4
#
#  | Global training round : 186/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.4
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.2
# Nine       - 97.5
#
#  | Global training round : 187/200 |
#
#
# Average test loss: 0.0464, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.7
# Nine       - 97.5
#
#  | Global training round : 188/200 |
#
#
# Average test loss: 0.0470, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.3
# Four       - 98.6
# Five       - 98.8
# Six        - 98.7
# Seven      - 97.8
# Eight      - 97.6
# Nine       - 97.4
#
#  | Global training round : 189/200 |
#
#
# Average test loss: 0.0469, Test accuracy: 9849/10000 (98.49%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.4
# Four       - 98.4
# Five       - 98.8
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.6
# Nine       - 97.5
#
#  | Global training round : 190/200 |
#
#
# Average test loss: 0.0464, Test accuracy: 9853/10000 (98.53%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.8
# Three      - 98.7
# Four       - 98.4
# Five       - 98.9
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.7
# Nine       - 97.5
#
#  | Global training round : 191/200 |
#
#
# Average test loss: 0.0462, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.4
# Four       - 98.7
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.7
# Nine       - 97.4
#
#  | Global training round : 192/200 |
#
#
# Average test loss: 0.0460, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.4
# Four       - 98.6
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.6
# Nine       - 97.4
#
#  | Global training round : 193/200 |
#
#
# Average test loss: 0.0461, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.4
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.7
# Nine       - 97.5
#
#  | Global training round : 194/200 |
#
#
# Average test loss: 0.0460, Test accuracy: 9853/10000 (98.53%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 99.0
# Three      - 98.6
# Four       - 98.6
# Five       - 98.4
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.4
# Nine       - 97.5
#
#  | Global training round : 195/200 |
#
#
# Average test loss: 0.0464, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.4
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.5
# Nine       - 97.4
#
#  | Global training round : 196/200 |
#
#
# Average test loss: 0.0459, Test accuracy: 9851/10000 (98.51%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.4
# Three      - 98.6
# Four       - 98.6
# Five       - 98.5
# Six        - 98.9
# Seven      - 97.7
# Eight      - 97.6
# Nine       - 97.6
#
#  | Global training round : 197/200 |
#
#
# Average test loss: 0.0459, Test accuracy: 9853/10000 (98.53%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.8
# Three      - 98.6
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.6
# Nine       - 97.5
#
#  | Global training round : 198/200 |
#
#
# Average test loss: 0.0462, Test accuracy: 9849/10000 (98.49%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.9
# Seven      - 97.9
# Eight      - 97.6
# Nine       - 97.4
#
#  | Global training round : 199/200 |
#
#
# Average test loss: 0.0458, Test accuracy: 9852/10000 (98.52%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 98.8
# Three      - 98.6
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.7
# Nine       - 97.3
#
#  | Global training round : 200/200 |
#
#
# Average test loss: 0.0455, Test accuracy: 9856/10000 (98.56%)
#
# Class      - Accuracy
# Zero       - 99.7
# One        - 99.5
# Two        - 99.0
# Three      - 98.6
# Four       - 98.6
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.8
# Nine       - 97.3
# Last 10 updates results
#
# Average test loss: 0.0459, Test accuracy: 9849/10000 (98.49%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.6
# Nine       - 97.4
# Global accuracies:  [25.54, 46.92, 64.4, 81.72, 87.73, 90.03, 91.69, 92.55, 93.14, 93.71, 94.09, 94.42, 94.71, 95.0, 95.18, 95.34, 95.58, 95.73, 95.82, 95.94, 96.1, 96.21, 96.29, 96.27, 96.35, 96.49, 96.56, 96.61, 96.7, 96.69, 96.86, 96.88, 96.89, 96.89, 97.01, 97.09, 97.09, 97.15, 97.17, 97.23, 97.2, 97.21, 97.26, 97.29, 97.29, 97.32, 97.33, 97.41, 97.4, 97.42, 97.44, 97.47, 97.43, 97.52, 97.55, 97.56, 97.56, 97.54, 97.64, 97.65, 97.67, 97.68, 97.69, 97.7, 97.67, 97.71, 97.75, 97.73, 97.73, 97.79, 97.82, 97.85, 97.81, 97.88, 97.89, 97.9, 97.85, 97.89, 97.88, 97.95, 97.95, 97.91, 97.94, 97.94, 97.95, 97.92, 97.92, 97.98, 97.94, 97.96, 98.0, 98.0, 98.01, 97.99, 98.06, 98.01, 98.01, 98.04, 98.06, 98.09, 98.08, 98.06, 98.08, 98.11, 98.1, 98.12, 98.16, 98.16, 98.2, 98.2, 98.22, 98.19, 98.19, 98.24, 98.28, 98.21, 98.24, 98.25, 98.28, 98.26, 98.27, 98.3, 98.25, 98.3, 98.31, 98.3, 98.3, 98.26, 98.29, 98.3, 98.33, 98.35, 98.3, 98.27, 98.3, 98.27, 98.3, 98.3, 98.32, 98.36, 98.35, 98.35, 98.38, 98.34, 98.39, 98.42, 98.36, 98.4, 98.37, 98.38, 98.4, 98.38, 98.45, 98.4, 98.45, 98.4, 98.4, 98.38, 98.42, 98.38, 98.37, 98.44, 98.37, 98.39, 98.41, 98.44, 98.41, 98.4, 98.45, 98.47, 98.44, 98.42, 98.4, 98.43, 98.45, 98.45, 98.46, 98.45, 98.48, 98.48, 98.44, 98.47, 98.44, 98.46, 98.43, 98.46, 98.46, 98.5, 98.49, 98.53, 98.48, 98.48, 98.5, 98.53, 98.46, 98.51, 98.53, 98.49, 98.52, 98.56, 98.49]
# Class 7 accuracies:  [87.35, 88.72, 88.42, 86.87, 89.11, 90.95, 91.44, 92.12, 92.32, 93.0, 93.09, 93.68, 93.39, 94.07, 94.16, 94.26, 94.26, 94.16, 94.16, 94.16, 94.65, 94.55, 95.04, 94.84, 94.84, 95.14, 94.84, 95.14, 95.43, 95.14, 95.72, 95.82, 95.72, 95.82, 95.82, 95.82, 95.72, 95.82, 96.01, 95.91, 95.72, 96.01, 96.01, 95.91, 95.82, 96.01, 96.01, 96.21, 96.21, 96.21, 96.11, 96.21, 96.21, 96.3, 96.3, 96.3, 96.3, 96.3, 96.4, 96.4, 96.3, 96.4, 96.4, 96.3, 96.21, 96.4, 96.3, 96.5, 96.3, 96.4, 96.4, 96.5, 96.5, 96.69, 96.4, 96.69, 96.89, 96.69, 96.6, 96.79, 96.79, 96.79, 96.89, 96.6, 96.69, 96.69, 96.79, 96.79, 96.79, 96.6, 96.89, 96.98, 96.98, 96.89, 96.89, 96.98, 96.89, 96.89, 96.98, 96.98, 96.89, 96.98, 96.89, 96.98, 96.98, 97.08, 97.08, 97.18, 96.98, 97.18, 97.08, 97.28, 97.37, 97.28, 97.08, 97.37, 97.28, 97.18, 97.37, 97.37, 97.37, 97.28, 97.37, 97.37, 97.37, 97.28, 97.37, 97.18, 97.28, 97.37, 97.37, 97.47, 97.37, 97.37, 97.37, 97.47, 97.37, 97.37, 97.47, 97.47, 97.47, 97.47, 97.57, 97.37, 97.67, 97.57, 97.47, 97.67, 97.47, 97.67, 97.67, 97.67, 97.57, 97.57, 97.67, 97.57, 97.47, 97.57, 97.57, 97.57, 97.57, 97.57, 97.57, 97.67, 97.57, 97.67, 97.57, 97.47, 97.47, 97.57, 97.57, 97.47, 97.47, 97.47, 97.47, 97.57, 97.47, 97.57, 97.86, 97.86, 97.57, 97.86, 97.67, 97.67, 97.57, 97.96, 97.47, 97.76, 97.86, 97.47, 97.47, 97.57, 97.86, 97.67, 97.67, 97.67, 97.67, 97.86, 97.57, 97.57, 97.57]
# trust Weightes : {0: 0.017079650112654606, 1: 0.018720277188082383, 2: 0.0, 3: 0.01596920830131886, 4: 0.0, 5: 0.015885366523043204, 6: 0.016676960315637174, 7: 0.015236527494530439, 8: 0.0, 9: 0.01645909146050469, 10: 0.020140995090848945, 11: 0.0, 12: 0.0, 13: 0.0, 14: 0.017486888948113097, 15: 0.01910121195101201, 16: 0.0, 17: 0.0, 18: 0.01394746532396503, 19: 0.017615246318502562, 20: 0.0, 21: 0.0, 22: 0.0, 23: 0.0, 24: 0.0, 25: 0.0, 26: 0.016422999026237485, 27: 0.01797687039088734, 28: 0.0, 29: 0.0, 30: 0.014723703559128222, 31: 0.02120590591310128, 32: 0.0, 33: 0.01651624055413033, 34: 0.0, 35: 0.0, 36: 0.018064739712272106, 37: 0.0, 38: 0.018408215215311375, 39: 0.011751049814055937, 40: 0.013906299103020887, 41: 0.010345915745474913, 42: 0.015200124151372027, 43: 0.0, 44: 0.01728603322611908, 45: 0.013970151685537804, 46: 0.0, 47: 0.02259450878809098, 48: 0.01399133102959631, 49: 0.020469897522040478, 50: 0.014666787693250409, 51: 0.01820888566355559, 52: 0.014859127315882887, 53: 0.017799821756537746, 54: 0.012771925292470785, 55: 0.0, 56: 0.015497086435713537, 57: 0.0, 58: 0.020690034970850295, 59: 0.01920288109960375, 60: 0.0, 61: 0.015353400288418409, 62: 0.0, 63: 0.016151248891028, 64: 0.017527394495288055, 65: 0.019705953923781622, 66: 0.01756687848145352, 67: 0.014665040673853458, 68: 0.01674166950536015, 69: 0.01769968857380533, 70: 0.019966218785372282, 71: 0.018830581358053527, 72: 0.013428692144289952, 73: 0.0, 74: 0.017360774757746934, 75: 0.0, 76: 0.01597514518640858, 77: 0.0, 78: 0.013224131436415482, 79: 0.015513817471147941, 80: 0.0, 81: 0.014009444229126805, 82: 0.0, 83: 0.016416856630869475, 84: 0.01878124964056454, 85: 0.013839273476734821, 86: 0.018324726518328515, 87: 0.0, 88: 0.0213646981380503, 89: 0.015192892850270071, 90: 0.0, 91: 0.0, 92: 0.0, 93: 0.0, 94: 0.01411533130895271, 95: 0.0, 96: 0.017395466542224822, 97: 0.0, 98: 0.0, 99: 0.0}
# Test loss: [2.2252, 1.9602, 1.4723, 1.0357, 0.6415, 0.4121, 0.3281, 0.2787, 0.2482, 0.2238, 0.206, 0.1939, 0.1815, 0.1711, 0.1638, 0.1566, 0.149, 0.1437, 0.1384, 0.1344, 0.1298, 0.1258, 0.1222, 0.1194, 0.116, 0.1128, 0.1117, 0.1084, 0.1075, 0.1048, 0.1022, 0.1017, 0.0992, 0.0983, 0.0956, 0.0947, 0.0934, 0.0916, 0.0918, 0.09, 0.0886, 0.0886, 0.0862, 0.0857, 0.0849, 0.083, 0.0826, 0.0827, 0.0809, 0.0803, 0.08, 0.0788, 0.0786, 0.0778, 0.0763, 0.0767, 0.0759, 0.0753, 0.0747, 0.0737, 0.0733, 0.0731, 0.0722, 0.0724, 0.0714, 0.071, 0.0698, 0.07, 0.0701, 0.0684, 0.0683, 0.0678, 0.0676, 0.0672, 0.067, 0.0661, 0.0665, 0.0658, 0.0656, 0.0649, 0.0643, 0.065, 0.0644, 0.0639, 0.0637, 0.0632, 0.0633, 0.0625, 0.0624, 0.0619, 0.0614, 0.0616, 0.0609, 0.0606, 0.0604, 0.0601, 0.0604, 0.0599, 0.0603, 0.0597, 0.0594, 0.059, 0.0585, 0.0584, 0.0587, 0.0584, 0.0582, 0.0579, 0.0569, 0.057, 0.0568, 0.057, 0.057, 0.0561, 0.0557, 0.0562, 0.0555, 0.056, 0.0554, 0.0552, 0.0545, 0.0543, 0.0544, 0.0536, 0.0541, 0.0542, 0.0533, 0.0537, 0.0538, 0.0543, 0.0539, 0.0536, 0.0533, 0.0533, 0.0531, 0.053, 0.0523, 0.0528, 0.0525, 0.0518, 0.0518, 0.0518, 0.0512, 0.0517, 0.0511, 0.051, 0.051, 0.0504, 0.0508, 0.0506, 0.0505, 0.0505, 0.0501, 0.0507, 0.0499, 0.0508, 0.0498, 0.0502, 0.05, 0.0499, 0.0494, 0.0491, 0.0495, 0.0496, 0.0489, 0.0482, 0.0485, 0.0487, 0.0482, 0.0483, 0.0482, 0.0487, 0.0479, 0.0477, 0.048, 0.0482, 0.048, 0.0483, 0.0476, 0.0473, 0.0474, 0.0476, 0.0477, 0.0474, 0.0473, 0.048, 0.0464, 0.047, 0.0469, 0.0464, 0.0462, 0.046, 0.0461, 0.046, 0.0464, 0.0459, 0.0459, 0.0462, 0.0458, 0.0455, 0.0459]
# Attack succes rate: 0.29
# Average CPU aggregation runtime: 0.002921973466873169
#
# --> End of Experiment.
