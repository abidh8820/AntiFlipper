# %%
    detect = [0, 1, 2, 5, 6, 8, 12, 15]
    actual =  [0, 5, 15, 2, 6, 12, 8, 1]
    
    #detect = d2l(detected)
    actual = sorted(actual)
    detect = sorted(detect)

    print(actual)
    print(detect)

    list1 = actual
    list2 = detect

    set1 = set(list1)
    set2 = set(list2)

    # Find common elements (intersection)
    common_elements = set1.intersection(set2)

    # Remove common elements from both lists
    list1_after = [item for item in list1 if item not in common_elements]
    list2_after = [item for item in list2 if item not in common_elements]
    
    #print(len(actual))
    #print(len(detect))
    Dataset = "CIFAR10"
    Data_Distribution = "IID"

    print('Dataset = ',Dataset,"   Distribution : ",Data_Distribution)
    print("----------------------------------------------------------")
    if (actual)==(detect):
      print("SUCCESSFULLY DETECTED ALL ",len(actual)," nodes")

    elif (actual)!=(detect):
      print("UNSUCCESSFUL")
      print("ACTUAL BAD Nodes = " ,len(actual)," nodes")
      print("DETECTED BAD Nodes = " ,len(detect)," nodes")
      if len(list1_after)==0:
        print("MISCLASSIFICATION")
      elif len(list2_after)==0:
        print("UNDETECTED")
      else :
        print("OHNO")
      print("")
      print("UNDETECTED BAD Nodes = " ,len(list1_after),"  nodes : ",list1_after)
      print("WRONGLY DETECTED BAD Nodes = " ,len(list2_after),"  nodes : ",list2_after)
# Out:
# [0, 1, 2, 5, 6, 8, 12, 15]
# [0, 1, 2, 5, 6, 8, 12, 15]
# Dataset =  CIFAR10    Distribution :  IID
# ----------------------------------------------------------
# SUCCESSFULLY DETECTED ALL  8  nodes

# %%
global_accurices = {0: 10.0, 1: 10.07, 2: 19.75, 3: 33.31, 4: 41.88, 5: 49.58, 6: 55.589999999999996, 7: 57.78, 8: 61.3, 9: 64.11, 10: 65.77, 11: 65.82000000000001, 12: 67.45, 13: 68.33, 14: 67.75, 15: 68.56, 16: 69.26, 17: 69.21000000000001, 18: 69.44, 19: 69.04, 20: 69.81, 21: 70.28, 22: 69.69999999999999, 23: 70.27, 24: 70.61, 25: 70.74000000000001, 26: 70.3, 27: 71.14, 28: 70.78, 29: 70.63000000000001, 30: 70.87, 31: 70.93, 32: 70.97, 33: 70.98, 34: 71.28999999999999, 35: 71.57, 36: 71.45, 37: 71.39999999999999, 38: 71.63000000000001, 39: 71.69, 40: 71.50999999999999, 41: 71.56, 42: 71.81, 43: 71.83, 44: 71.57, 45: 71.66, 46: 71.97, 47: 72.28, 48: 71.7, 49: 71.89999999999999, 50: 71.89, 51: 72.16, 52: 71.8, 53: 72.17, 54: 71.56, 55: 71.77, 56: 71.93, 57: 71.97, 58: 71.66, 59: 71.99, 60: 71.93, 61: 71.89, 62: 72.07000000000001, 63: 72.06, 64: 72.00999999999999, 65: 71.84, 66: 72.42, 67: 71.89999999999999, 68: 72.1, 69: 71.8, 70: 71.49, 71: 72.1, 72: 71.78999999999999, 73: 71.63000000000001, 74: 72.16, 75: 72.36, 76: 71.89999999999999, 77: 72.27, 78: 72.35000000000001, 79: 72.39, 80: 72.75, 81: 72.33000000000001, 82: 72.13000000000001, 83: 71.93, 84: 71.94, 85: 71.88, 86: 72.06, 87: 72.39, 88: 72.02, 89: 72.47, 90: 72.15, 91: 72.28999999999999, 92: 72.14, 93: 72.32, 94: 72.08, 95: 72.72999999999999, 96: 72.03, 97: 72.49, 98: 72.23, 99: 72.3}
sum = 0
for a,b in global_accurices.items():
    sum = sum+b
print(sum/100)
# Out:
# 68.2285

# %%
import statistics
aggg = [67.52397155761719, 67.06396484375, 68.45027160644531, 70.66310119628906, 63.81119918823242, 65.3056640625, 62.525535583496094, 69.7204818725586, 66.41327667236328, 68.0880355834961, 70.82617950439453, 67.38396453857422, 66.59069061279297, 69.25071716308594, 66.5334701538086, 59.9126091003418, 49.61286544799805, 51.773536682128906, 43.82988739013672, 45.87001419067383, 44.889854431152344, 46.62723159790039, 50.19811248779297, 42.67884826660156, 45.98169708251953, 46.5241584777832, 47.21046447753906, 42.1954231262207, 43.07593536376953, 42.50646209716797, 48.339073181152344, 44.79344177246094, 45.204864501953125, 43.01465606689453, 48.301761627197266, 42.10960006713867, 48.13727951049805, 43.030433654785156, 46.998207092285156, 45.42009735107422, 42.86316680908203, 44.58156967163086, 47.720481872558594, 44.75193786621094, 42.05305480957031, 46.04131317138672, 47.62752151489258, 46.12895965576172, 46.24668884277344, 43.626529693603516, 44.407615661621094, 44.109825134277344, 43.73215866088867, 44.173439025878906, 41.734432220458984, 44.3656005859375, 43.343936920166016, 42.93164825439453, 43.644126892089844, 42.94803237915039, 45.367103576660156, 43.901214599609375, 48.14352035522461, 47.67839813232422, 42.91164779663086, 42.66950225830078, 46.28278350830078, 41.884063720703125, 45.25459289550781, 41.13702392578125, 47.338462829589844, 42.81283187866211, 43.93328094482422, 46.72627258300781, 45.99776077270508, 42.00678253173828, 50.60627365112305, 42.85472106933594, 44.97391891479492, 44.82377624511719, 45.22809600830078, 42.566463470458984, 47.01830291748047, 42.20848083496094, 42.380958557128906, 45.749534606933594, 45.365760803222656, 44.350975036621094, 46.90959930419922, 45.68716812133789, 41.633888244628906, 43.533470153808594, 42.93107223510742, 45.185569763183594, 44.96160125732422, 43.129920959472656, 47.017822265625, 43.61542510986328, 42.38115310668945, 48.685054779052734]
statistics.mean(aggg)
# Out:
# 48.43263328552246

# %%
num_agents = 20
rounds = 100
trust = [[0.0 for _ in range(num_agents)] for _ in range(rounds)]

# %%
malcious_nodes = [actual
for x in range(0,200):
    h = []
    m = []
    for a,b in trust[x].items():
        if a in malcious_nodes:
            m.append(b)
        else :
            h.append(b)
    print("Round ",x," Honest Low: ",f"{min(h) : .4f}"," Honest High: ",f"{max(h) : .4f}"," Malicious Low: ",f"{min(m) : .4f}"," Malicious High: ",f"{max(m) : .4f}")
# Out:
# Round  5  Honest Low:   0.0156  Honest High:   0.0184  Malicious Low:   0.0000  Malicious High:   0.0004
# Round  6  Honest Low:   0.0150  Honest High:   0.0188  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  7  Honest Low:   0.0153  Honest High:   0.0187  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  8  Honest Low:   0.0154  Honest High:   0.0188  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  9  Honest Low:   0.0152  Honest High:   0.0187  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  10  Honest Low:   0.0150  Honest High:   0.0186  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  11  Honest Low:   0.0150  Honest High:   0.0186  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  12  Honest Low:   0.0150  Honest High:   0.0186  Malicious Low:   0.0000  Malicious High:   0.0000
# Round  13  Honest Low:   0.0150  Honest High:   0.0186  Malicious Low:   0.0000  Malicious High:   0.0000
# ...
