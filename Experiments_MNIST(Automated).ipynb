# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            #================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np                                                                                          
import torch
from utils import *
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#
# Out:
# 2025-01-22 23:38:01.655704: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-22 23:38:01.679122: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-22 23:38:02.064368: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'NON_IID'
ALPHA = 1
NUM_PEERS = 100 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)


CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 200 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda:0"
else:
    DEVICE = "cpu"
print(DEVICE)
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1
# Out:
# cuda:0

# %%
## Everything at Once
for attackPercentage in [0.40]:
    RULE = 'localEval'
    ATTACK_TYPE='label_flipping'
    MALICIOUS_BEHAVIOR_RATE = 1
    for atr in [attackPercentage]:
        run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
                frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                    criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                    local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                    attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                    malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                    source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
                class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
                rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
#
# --> Starting experiment...
# The function distribute_dataset is from the module sampling.
# -->  Loading of MNIST dataset
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: NON_IID
# Aggregation rule: localEval
# Attack Type: label_flipping
# Attackers Ratio: 40.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Average test loss: 2.2252, Test accuracy: 2554/10000 (25.54%)
#
# Class      - Accuracy
# Zero       - 4.3
# One        - 5.1
# Two        - 23.0
# Three      - 64.3
# Four       - 0.7
# Five       - 0.6
# Six        - 0.4
# Seven      - 87.3
# Eight      - 0.0
# Nine       - 64.9
#
#  | Global training round : 2/200 |
#
#
# Average test loss: 1.9601, Test accuracy: 4688/10000 (46.88%)
#
# Class      - Accuracy
# Zero       - 70.4
# One        - 92.9
# Two        - 36.5
# Three      - 81.5
# Four       - 9.5
# Five       - 15.1
# Six        - 8.0
# Seven      - 88.3
# Eight      - 23.1
# Nine       - 30.3
#
#  | Global training round : 3/200 |
#
#
# Average test loss: 1.4820, Test accuracy: 6406/10000 (64.06%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 93.7
# Two        - 45.2
# Three      - 87.5
# Four       - 48.6
# Five       - 34.4
# Six        - 47.5
# Seven      - 87.6
# Eight      - 26.3
# Nine       - 65.9
#
#  | Global training round : 4/200 |
#
#
# Average test loss: 1.1112, Test accuracy: 8007/10000 (80.07%)
#
# Class      - Accuracy
# Zero       - 96.0
# One        - 93.9
# Two        - 81.6
# Three      - 86.8
# Four       - 77.2
# Five       - 57.2
# Six        - 79.9
# Seven      - 85.4
# Eight      - 51.8
# Nine       - 85.7
#
#  | Global training round : 5/200 |
#
#
# Average test loss: 0.8528, Test accuracy: 8701/10000 (87.01%)
#
# Class      - Accuracy
# Zero       - 97.2
# One        - 95.8
# Two        - 89.6
# Three      - 87.5
# Four       - 83.6
# Five       - 75.0
# Six        - 90.8
# Seven      - 85.6
# Eight      - 72.6
# Nine       - 89.7
#
#  | Global training round : 6/200 |
#
#
# Average test loss: 0.6110, Test accuracy: 9019/10000 (90.19%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 97.0
# Two        - 91.3
# Three      - 89.8
# Four       - 90.5
# Five       - 81.7
# Six        - 94.6
# Seven      - 86.5
# Eight      - 80.3
# Nine       - 91.1
#
#  | Global training round : 7/200 |
#
#
# Average test loss: 0.4237, Test accuracy: 9182/10000 (91.82%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.0
# Two        - 92.4
# Three      - 91.2
# Four       - 92.6
# Five       - 85.4
# Six        - 95.3
# Seven      - 89.5
# Eight      - 82.2
# Nine       - 92.3
#
#  | Global training round : 8/200 |
#
#
# Average test loss: 0.3020, Test accuracy: 9220/10000 (92.20%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 91.0
# Three      - 91.5
# Four       - 92.8
# Five       - 87.9
# Six        - 95.5
# Seven      - 90.8
# Eight      - 82.1
# Nine       - 92.4
#
#  | Global training round : 9/200 |
#
#
# Average test loss: 0.2571, Test accuracy: 9296/10000 (92.96%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 91.6
# Three      - 92.4
# Four       - 93.2
# Five       - 89.2
# Six        - 96.8
# Seven      - 91.4
# Eight      - 84.2
# Nine       - 92.6
#
#  | Global training round : 10/200 |
#
#
# Average test loss: 0.2283, Test accuracy: 9379/10000 (93.79%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 91.9
# Three      - 93.7
# Four       - 94.1
# Five       - 90.9
# Six        - 97.0
# Seven      - 92.4
# Eight      - 86.2
# Nine       - 93.4
#
#  | Global training round : 11/200 |
#
#
# Average test loss: 0.2090, Test accuracy: 9419/10000 (94.19%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 92.2
# Three      - 93.9
# Four       - 94.5
# Five       - 92.3
# Six        - 97.0
# Seven      - 92.8
# Eight      - 87.9
# Nine       - 93.4
#
#  | Global training round : 12/200 |
#
#
# Average test loss: 0.1944, Test accuracy: 9441/10000 (94.41%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 92.6
# Three      - 93.7
# Four       - 94.8
# Five       - 93.4
# Six        - 96.5
# Seven      - 93.5
# Eight      - 88.3
# Nine       - 93.1
#
#  | Global training round : 13/200 |
#
#
# Average test loss: 0.1821, Test accuracy: 9474/10000 (94.74%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 92.8
# Three      - 94.2
# Four       - 95.1
# Five       - 94.6
# Six        - 96.7
# Seven      - 93.1
# Eight      - 88.9
# Nine       - 94.0
#
#  | Global training round : 14/200 |
#
#
# Average test loss: 0.1717, Test accuracy: 9508/10000 (95.08%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 93.0
# Three      - 94.7
# Four       - 95.0
# Five       - 94.7
# Six        - 96.6
# Seven      - 94.2
# Eight      - 89.7
# Nine       - 94.6
#
#  | Global training round : 15/200 |
#
#
# Average test loss: 0.1640, Test accuracy: 9528/10000 (95.28%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 93.7
# Three      - 95.1
# Four       - 94.8
# Five       - 94.8
# Six        - 97.1
# Seven      - 94.2
# Eight      - 90.0
# Nine       - 94.8
#
#  | Global training round : 16/200 |
#
#
# Average test loss: 0.1560, Test accuracy: 9534/10000 (95.34%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 94.1
# Three      - 95.4
# Four       - 95.2
# Five       - 94.7
# Six        - 97.0
# Seven      - 94.1
# Eight      - 90.2
# Nine       - 94.5
#
#  | Global training round : 17/200 |
#
#
# Average test loss: 0.1493, Test accuracy: 9566/10000 (95.66%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 94.8
# Three      - 95.3
# Four       - 95.7
# Five       - 95.7
# Six        - 97.0
# Seven      - 94.3
# Eight      - 90.8
# Nine       - 94.7
#
#  | Global training round : 18/200 |
#
#
# Average test loss: 0.1433, Test accuracy: 9575/10000 (95.75%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 95.1
# Three      - 95.4
# Four       - 95.8
# Five       - 95.7
# Six        - 97.1
# Seven      - 94.3
# Eight      - 91.2
# Nine       - 94.8
#
#  | Global training round : 19/200 |
#
#
# Average test loss: 0.1380, Test accuracy: 9586/10000 (95.86%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 95.1
# Three      - 95.4
# Four       - 96.0
# Five       - 96.3
# Six        - 97.2
# Seven      - 94.2
# Eight      - 91.5
# Nine       - 94.9
#
#  | Global training round : 20/200 |
#
#
# Average test loss: 0.1343, Test accuracy: 9596/10000 (95.96%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 95.4
# Three      - 95.9
# Four       - 96.0
# Five       - 96.2
# Six        - 97.1
# Seven      - 94.4
# Eight      - 91.3
# Nine       - 95.0
#
#  | Global training round : 21/200 |
#
#
# Average test loss: 0.1295, Test accuracy: 9606/10000 (96.06%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 95.4
# Three      - 95.5
# Four       - 96.0
# Five       - 96.4
# Six        - 97.3
# Seven      - 94.6
# Eight      - 92.0
# Nine       - 95.0
#
#  | Global training round : 22/200 |
#
#
# Average test loss: 0.1259, Test accuracy: 9616/10000 (96.16%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 95.7
# Three      - 96.3
# Four       - 96.0
# Five       - 96.5
# Six        - 97.3
# Seven      - 94.4
# Eight      - 92.0
# Nine       - 95.1
#
#  | Global training round : 23/200 |
#
#
# Average test loss: 0.1225, Test accuracy: 9631/10000 (96.31%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 95.8
# Three      - 96.2
# Four       - 96.1
# Five       - 96.7
# Six        - 97.5
# Seven      - 95.1
# Eight      - 92.1
# Nine       - 95.0
#
#  | Global training round : 24/200 |
#
#
# Average test loss: 0.1194, Test accuracy: 9637/10000 (96.37%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 95.8
# Three      - 96.3
# Four       - 96.1
# Five       - 96.7
# Six        - 97.7
# Seven      - 94.8
# Eight      - 92.3
# Nine       - 95.7
#
#  | Global training round : 25/200 |
#
#
# Average test loss: 0.1163, Test accuracy: 9638/10000 (96.38%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 95.6
# Three      - 95.9
# Four       - 96.2
# Five       - 96.9
# Six        - 97.4
# Seven      - 94.8
# Eight      - 92.9
# Nine       - 95.6
#
#  | Global training round : 26/200 |
#
#
# Average test loss: 0.1122, Test accuracy: 9650/10000 (96.50%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 96.0
# Three      - 96.7
# Four       - 96.0
# Five       - 96.9
# Six        - 97.5
# Seven      - 95.1
# Eight      - 92.9
# Nine       - 95.7
#
#  | Global training round : 27/200 |
#
#
# Average test loss: 0.1119, Test accuracy: 9655/10000 (96.55%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 95.9
# Three      - 96.6
# Four       - 96.5
# Five       - 97.3
# Six        - 97.6
# Seven      - 95.0
# Eight      - 92.5
# Nine       - 95.6
#
#  | Global training round : 28/200 |
#
#
# Average test loss: 0.1087, Test accuracy: 9659/10000 (96.59%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.0
# Three      - 96.7
# Four       - 96.5
# Five       - 97.1
# Six        - 97.5
# Seven      - 95.3
# Eight      - 92.9
# Nine       - 95.7
#
#  | Global training round : 29/200 |
#
#
# Average test loss: 0.1074, Test accuracy: 9672/10000 (96.72%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 96.0
# Three      - 96.8
# Four       - 96.6
# Five       - 97.0
# Six        - 97.5
# Seven      - 95.4
# Eight      - 93.4
# Nine       - 95.7
#
#  | Global training round : 30/200 |
#
#
# Average test loss: 0.1049, Test accuracy: 9674/10000 (96.74%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.4
# Three      - 96.8
# Four       - 96.2
# Five       - 97.2
# Six        - 97.4
# Seven      - 95.3
# Eight      - 93.8
# Nine       - 95.8
#
#  | Global training round : 31/200 |
#
#
# Average test loss: 0.1022, Test accuracy: 9681/10000 (96.81%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 96.1
# Three      - 96.8
# Four       - 96.7
# Five       - 97.5
# Six        - 97.5
# Seven      - 95.5
# Eight      - 93.8
# Nine       - 95.9
#
#  | Global training round : 32/200 |
#
#
# Average test loss: 0.1020, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 96.1
# Three      - 96.7
# Four       - 96.5
# Five       - 97.8
# Six        - 97.8
# Seven      - 95.5
# Eight      - 93.7
# Nine       - 96.1
#
#  | Global training round : 33/200 |
#
#
# Average test loss: 0.0992, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 96.7
# Three      - 97.1
# Four       - 96.1
# Five       - 97.3
# Six        - 97.7
# Seven      - 95.6
# Eight      - 94.4
# Nine       - 96.1
#
#  | Global training round : 34/200 |
#
#
# Average test loss: 0.0983, Test accuracy: 9697/10000 (96.97%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 96.5
# Three      - 97.1
# Four       - 96.5
# Five       - 97.6
# Six        - 97.6
# Seven      - 95.8
# Eight      - 94.1
# Nine       - 96.0
#
#  | Global training round : 35/200 |
#
#
# Average test loss: 0.0960, Test accuracy: 9697/10000 (96.97%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 96.4
# Three      - 97.1
# Four       - 96.5
# Five       - 97.9
# Six        - 97.7
# Seven      - 95.7
# Eight      - 94.3
# Nine       - 96.3
#
#  | Global training round : 36/200 |
#
#
# Average test loss: 0.0948, Test accuracy: 9708/10000 (97.08%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 96.6
# Three      - 97.0
# Four       - 96.6
# Five       - 97.6
# Six        - 97.9
# Seven      - 95.7
# Eight      - 94.8
# Nine       - 96.3
#
#  | Global training round : 37/200 |
#
#
# Average test loss: 0.0933, Test accuracy: 9707/10000 (97.07%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 96.7
# Three      - 97.0
# Four       - 96.5
# Five       - 98.1
# Six        - 97.7
# Seven      - 95.7
# Eight      - 94.6
# Nine       - 96.3
#
#  | Global training round : 38/200 |
#
#
# Average test loss: 0.0921, Test accuracy: 9710/10000 (97.10%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 96.9
# Three      - 96.9
# Four       - 96.7
# Five       - 98.1
# Six        - 97.5
# Seven      - 95.8
# Eight      - 94.8
# Nine       - 96.1
#
#  | Global training round : 39/200 |
#
#
# Average test loss: 0.0921, Test accuracy: 9716/10000 (97.16%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 96.8
# Three      - 97.3
# Four       - 96.5
# Five       - 97.9
# Six        - 97.8
# Seven      - 96.0
# Eight      - 94.5
# Nine       - 96.2
#
#  | Global training round : 40/200 |
#
#
# Average test loss: 0.0907, Test accuracy: 9717/10000 (97.17%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.8
# Three      - 97.1
# Four       - 96.8
# Five       - 98.1
# Six        - 97.8
# Seven      - 95.9
# Eight      - 94.7
# Nine       - 96.1
#
#  | Global training round : 41/200 |
#
#
# Average test loss: 0.0892, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.9
# Three      - 96.9
# Four       - 96.7
# Five       - 98.1
# Six        - 98.0
# Seven      - 95.7
# Eight      - 95.0
# Nine       - 96.3
#
#  | Global training round : 42/200 |
#
#
# Average test loss: 0.0891, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 96.9
# Three      - 97.1
# Four       - 96.5
# Five       - 98.1
# Six        - 98.0
# Seven      - 96.1
# Eight      - 94.5
# Nine       - 96.3
#
#  | Global training round : 43/200 |
#
#
# Average test loss: 0.0865, Test accuracy: 9728/10000 (97.28%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 96.9
# Three      - 97.2
# Four       - 96.8
# Five       - 98.3
# Six        - 98.0
# Seven      - 96.2
# Eight      - 94.8
# Nine       - 96.4
#
#  | Global training round : 44/200 |
#
#
# Average test loss: 0.0861, Test accuracy: 9726/10000 (97.26%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.0
# Three      - 97.3
# Four       - 96.7
# Five       - 98.0
# Six        - 98.0
# Seven      - 96.0
# Eight      - 95.1
# Nine       - 96.1
#
#  | Global training round : 45/200 |
#
#
# Average test loss: 0.0851, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.2
# Three      - 97.4
# Four       - 96.8
# Five       - 98.2
# Six        - 97.8
# Seven      - 95.9
# Eight      - 95.1
# Nine       - 96.4
#
#  | Global training round : 46/200 |
#
#
# Average test loss: 0.0835, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.1
# Three      - 97.5
# Four       - 96.6
# Five       - 98.3
# Six        - 97.9
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.3
#
#  | Global training round : 47/200 |
#
#
# Average test loss: 0.0831, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.2
# Three      - 97.4
# Four       - 97.3
# Five       - 98.3
# Six        - 98.0
# Seven      - 96.1
# Eight      - 94.9
# Nine       - 96.4
#
#  | Global training round : 48/200 |
#
#
# Average test loss: 0.0834, Test accuracy: 9740/10000 (97.40%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.3
# Three      - 97.5
# Four       - 96.6
# Five       - 98.4
# Six        - 97.9
# Seven      - 96.0
# Eight      - 94.9
# Nine       - 96.6
#
#  | Global training round : 49/200 |
#
#
# Average test loss: 0.0815, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.2
# Three      - 97.5
# Four       - 97.1
# Five       - 98.5
# Six        - 98.1
# Seven      - 96.1
# Eight      - 95.0
# Nine       - 96.5
#
#  | Global training round : 50/200 |
#
#
# Average test loss: 0.0806, Test accuracy: 9748/10000 (97.48%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.3
# Three      - 97.5
# Four       - 97.1
# Five       - 98.3
# Six        - 98.1
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.6
#
#  | Global training round : 51/200 |
#
#
# Average test loss: 0.0807, Test accuracy: 9747/10000 (97.47%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.3
# Three      - 97.6
# Four       - 96.6
# Five       - 98.4
# Six        - 98.1
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.7
#
#  | Global training round : 52/200 |
#
#
# Average test loss: 0.0799, Test accuracy: 9747/10000 (97.47%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.3
# Three      - 97.6
# Four       - 96.8
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.1
# Eight      - 95.3
# Nine       - 96.7
#
#  | Global training round : 53/200 |
#
#
# Average test loss: 0.0794, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.3
# Three      - 97.6
# Four       - 96.8
# Five       - 98.3
# Six        - 98.1
# Seven      - 96.2
# Eight      - 95.3
# Nine       - 96.6
#
#  | Global training round : 54/200 |
#
#
# Average test loss: 0.0786, Test accuracy: 9748/10000 (97.48%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 97.3
# Three      - 97.5
# Four       - 96.8
# Five       - 98.1
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.3
# Nine       - 96.6
#
#  | Global training round : 55/200 |
#
#
# Average test loss: 0.0770, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.3
# Three      - 97.8
# Four       - 96.7
# Five       - 98.5
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.7
# Nine       - 96.9
#
#  | Global training round : 56/200 |
#
#
# Average test loss: 0.0778, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.3
# Three      - 97.7
# Four       - 96.7
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.4
# Eight      - 95.5
# Nine       - 96.7
#
#  | Global training round : 57/200 |
#
#
# Average test loss: 0.0766, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.2
# Three      - 97.7
# Four       - 97.0
# Five       - 98.2
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.5
# Nine       - 96.8
#
#  | Global training round : 58/200 |
#
#
# Average test loss: 0.0760, Test accuracy: 9759/10000 (97.59%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.3
# Three      - 97.7
# Four       - 96.8
# Five       - 98.3
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.9
# Nine       - 96.8
#
#  | Global training round : 59/200 |
#
#
# Average test loss: 0.0758, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.3
# Three      - 97.8
# Four       - 97.1
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.6
# Nine       - 96.8
#
#  | Global training round : 60/200 |
#
#
# Average test loss: 0.0745, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.3
# Three      - 97.8
# Four       - 97.1
# Five       - 98.4
# Six        - 98.1
# Seven      - 96.3
# Eight      - 95.9
# Nine       - 96.9
#
#  | Global training round : 61/200 |
#
#
# Average test loss: 0.0743, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.6
# Three      - 97.8
# Four       - 97.0
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.2
# Eight      - 96.0
# Nine       - 96.7
#
#  | Global training round : 62/200 |
#
#
# Average test loss: 0.0740, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.3
# Three      - 97.8
# Four       - 96.9
# Five       - 98.5
# Six        - 98.2
# Seven      - 96.3
# Eight      - 95.6
# Nine       - 97.1
#
#  | Global training round : 63/200 |
#
#
# Average test loss: 0.0733, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.5
# Three      - 97.8
# Four       - 96.9
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.7
# Nine       - 97.0
#
#  | Global training round : 64/200 |
#
#
# Average test loss: 0.0734, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 97.4
# Three      - 97.8
# Four       - 97.0
# Five       - 98.7
# Six        - 98.0
# Seven      - 96.4
# Eight      - 95.6
# Nine       - 96.9
#
#  | Global training round : 65/200 |
#
#
# Average test loss: 0.0724, Test accuracy: 9763/10000 (97.63%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.6
# Three      - 97.8
# Four       - 96.9
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.9
# Nine       - 96.7
#
#  | Global training round : 66/200 |
#
#
# Average test loss: 0.0719, Test accuracy: 9769/10000 (97.69%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.5
# Three      - 97.8
# Four       - 96.9
# Five       - 98.7
# Six        - 98.1
# Seven      - 96.3
# Eight      - 95.9
# Nine       - 97.2
#
#  | Global training round : 67/200 |
#
#
# Average test loss: 0.0708, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.5
# Three      - 97.8
# Four       - 97.1
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.3
# Eight      - 96.1
# Nine       - 97.1
#
#  | Global training round : 68/200 |
#
#
# Average test loss: 0.0709, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.5
# Three      - 97.8
# Four       - 97.1
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.7
# Eight      - 95.7
# Nine       - 96.9
#
#  | Global training round : 69/200 |
#
#
# Average test loss: 0.0710, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.6
# Three      - 97.8
# Four       - 97.1
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.3
# Eight      - 95.8
# Nine       - 97.1
#
#  | Global training round : 70/200 |
#
#
# Average test loss: 0.0693, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.6
# Three      - 97.9
# Four       - 97.5
# Five       - 98.8
# Six        - 98.1
# Seven      - 96.5
# Eight      - 96.0
# Nine       - 96.9
#
#  | Global training round : 71/200 |
#
#
# Average test loss: 0.0691, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.6
# Three      - 97.8
# Four       - 97.5
# Five       - 98.7
# Six        - 98.2
# Seven      - 96.5
# Eight      - 96.0
# Nine       - 96.9
#
#  | Global training round : 72/200 |
#
#
# Average test loss: 0.0688, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.6
# Three      - 97.9
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.6
# Eight      - 95.9
# Nine       - 97.1
#
#  | Global training round : 73/200 |
#
#
# Average test loss: 0.0687, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.6
# Three      - 97.9
# Four       - 97.1
# Five       - 98.8
# Six        - 98.2
# Seven      - 96.5
# Eight      - 95.9
# Nine       - 97.1
#
#  | Global training round : 74/200 |
#
#
# Average test loss: 0.0682, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.6
# Three      - 97.8
# Four       - 97.5
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.7
# Eight      - 95.9
# Nine       - 97.0
#
#  | Global training round : 75/200 |
#
#
# Average test loss: 0.0682, Test accuracy: 9779/10000 (97.79%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.7
# Three      - 97.9
# Four       - 97.5
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.5
# Eight      - 95.8
# Nine       - 97.3
#
#  | Global training round : 76/200 |
#
#
# Average test loss: 0.0670, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.7
# Three      - 97.9
# Four       - 97.7
# Five       - 98.5
# Six        - 98.2
# Seven      - 96.7
# Eight      - 96.1
# Nine       - 97.1
#
#  | Global training round : 77/200 |
#
#
# Average test loss: 0.0674, Test accuracy: 9784/10000 (97.84%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.7
# Three      - 97.9
# Four       - 97.7
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.0
# Nine       - 97.0
#
#  | Global training round : 78/200 |
#
#
# Average test loss: 0.0668, Test accuracy: 9784/10000 (97.84%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.7
# Three      - 97.9
# Four       - 97.3
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.0
# Nine       - 97.2
#
#  | Global training round : 79/200 |
#
#
# Average test loss: 0.0663, Test accuracy: 9784/10000 (97.84%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.5
# Three      - 97.9
# Four       - 97.4
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.2
# Nine       - 97.0
#
#  | Global training round : 80/200 |
#
#
# Average test loss: 0.0662, Test accuracy: 9788/10000 (97.88%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.7
# Three      - 97.9
# Four       - 97.7
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.0
# Nine       - 97.0
#
#  | Global training round : 81/200 |
#
#
# Average test loss: 0.0654, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 98.1
# Three      - 97.9
# Four       - 97.5
# Five       - 98.9
# Six        - 98.3
# Seven      - 96.7
# Eight      - 96.1
# Nine       - 97.2
#
#  | Global training round : 82/200 |
#
#
# Average test loss: 0.0665, Test accuracy: 9787/10000 (97.87%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.8
# Three      - 97.9
# Four       - 97.1
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 95.9
# Nine       - 97.4
#
#  | Global training round : 83/200 |
#
#
# Average test loss: 0.0652, Test accuracy: 9791/10000 (97.91%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 97.9
# Four       - 97.5
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.1
# Nine       - 97.3
#
#  | Global training round : 84/200 |
#
#
# Average test loss: 0.0649, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.8
# Three      - 97.9
# Four       - 97.4
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.4
#
#  | Global training round : 85/200 |
#
#
# Average test loss: 0.0651, Test accuracy: 9788/10000 (97.88%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.8
# Three      - 97.9
# Four       - 97.4
# Five       - 98.5
# Six        - 98.2
# Seven      - 96.8
# Eight      - 96.2
# Nine       - 97.2
#
#  | Global training round : 86/200 |
#
#
# Average test loss: 0.0642, Test accuracy: 9789/10000 (97.89%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 97.8
# Three      - 97.9
# Four       - 97.4
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.1
# Nine       - 97.3
#
#  | Global training round : 87/200 |
#
#
# Average test loss: 0.0645, Test accuracy: 9793/10000 (97.93%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 97.9
# Three      - 97.9
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.2
# Nine       - 97.3
#
#  | Global training round : 88/200 |
#
#
# Average test loss: 0.0633, Test accuracy: 9795/10000 (97.95%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 98.0
# Three      - 98.0
# Four       - 97.7
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.2
# Nine       - 97.4
#
#  | Global training round : 89/200 |
#
#
# Average test loss: 0.0638, Test accuracy: 9790/10000 (97.90%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.0
# Three      - 97.9
# Four       - 97.5
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.1
# Nine       - 97.3
#
#  | Global training round : 90/200 |
#
#
# Average test loss: 0.0631, Test accuracy: 9799/10000 (97.99%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.0
# Three      - 97.9
# Four       - 97.8
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.2
# Nine       - 97.4
#
#  | Global training round : 91/200 |
#
#
# Average test loss: 0.0628, Test accuracy: 9791/10000 (97.91%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.0
# Three      - 97.9
# Four       - 97.1
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.3
# Nine       - 97.4
#
#  | Global training round : 92/200 |
#
#
# Average test loss: 0.0632, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 97.9
# Three      - 98.0
# Four       - 97.9
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.2
# Nine       - 97.1
#
#  | Global training round : 93/200 |
#
#
# Average test loss: 0.0622, Test accuracy: 9800/10000 (98.00%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.0
# Three      - 97.9
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.5
# Nine       - 97.5
#
#  | Global training round : 94/200 |
#
#
# Average test loss: 0.0618, Test accuracy: 9798/10000 (97.98%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.9
# Three      - 98.0
# Four       - 97.6
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 95/200 |
#
#
# Average test loss: 0.0616, Test accuracy: 9799/10000 (97.99%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.5
# Nine       - 97.4
#
#  | Global training round : 96/200 |
#
#
# Average test loss: 0.0612, Test accuracy: 9796/10000 (97.96%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 98.0
# Three      - 98.0
# Four       - 97.3
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.7
# Nine       - 97.3
#
#  | Global training round : 97/200 |
#
#
# Average test loss: 0.0614, Test accuracy: 9800/10000 (98.00%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 98.1
# Four       - 97.5
# Five       - 98.4
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 98/200 |
#
#
# Average test loss: 0.0610, Test accuracy: 9802/10000 (98.02%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 97.9
# Three      - 98.2
# Four       - 97.7
# Five       - 98.5
# Six        - 98.3
# Seven      - 96.9
# Eight      - 96.5
# Nine       - 97.4
#
#  | Global training round : 99/200 |
#
#
# Average test loss: 0.0612, Test accuracy: 9807/10000 (98.07%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 98.2
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.1
# Eight      - 96.4
# Nine       - 97.3
#
#  | Global training round : 100/200 |
#
#
# Average test loss: 0.0608, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.2
# Two        - 98.0
# Three      - 98.0
# Four       - 97.8
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.4
# Nine       - 97.4
#
#  | Global training round : 101/200 |
#
#
# Average test loss: 0.0605, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.0
# Three      - 97.9
# Four       - 97.8
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.1
# Eight      - 96.4
# Nine       - 97.3
#
#  | Global training round : 102/200 |
#
#
# Average test loss: 0.0604, Test accuracy: 9800/10000 (98.00%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.0
# Three      - 98.0
# Four       - 97.6
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.4
# Nine       - 97.3
#
#  | Global training round : 103/200 |
#
#
# Average test loss: 0.0603, Test accuracy: 9798/10000 (97.98%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.2
# Two        - 98.0
# Three      - 98.1
# Four       - 97.5
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.3
# Nine       - 97.4
#
#  | Global training round : 104/200 |
#
#
# Average test loss: 0.0599, Test accuracy: 9802/10000 (98.02%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.0
# Three      - 98.1
# Four       - 97.7
# Five       - 98.4
# Six        - 98.4
# Seven      - 97.0
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 105/200 |
#
#
# Average test loss: 0.0600, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.1
# Three      - 98.0
# Four       - 97.7
# Five       - 98.4
# Six        - 98.3
# Seven      - 97.0
# Eight      - 96.5
# Nine       - 97.3
#
#  | Global training round : 106/200 |
#
#
# Average test loss: 0.0598, Test accuracy: 9804/10000 (98.04%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.0
# Three      - 98.2
# Four       - 97.5
# Five       - 98.7
# Six        - 98.3
# Seven      - 97.1
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 107/200 |
#
#
# Average test loss: 0.0596, Test accuracy: 9808/10000 (98.08%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.0
# Three      - 98.1
# Four       - 97.8
# Five       - 98.4
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 97.3
#
#  | Global training round : 108/200 |
#
#
# Average test loss: 0.0591, Test accuracy: 9810/10000 (98.10%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.0
# Three      - 98.0
# Four       - 98.3
# Five       - 98.4
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.5
# Nine       - 97.3
#
#  | Global training round : 109/200 |
#
#
# Average test loss: 0.0587, Test accuracy: 9812/10000 (98.12%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.1
# Four       - 98.2
# Five       - 98.4
# Six        - 98.4
# Seven      - 97.1
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 110/200 |
#
#
# Average test loss: 0.0583, Test accuracy: 9809/10000 (98.09%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.0
# Three      - 98.2
# Four       - 97.9
# Five       - 98.4
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.5
# Nine       - 97.4
#
#  | Global training round : 111/200 |
#
#
# Average test loss: 0.0585, Test accuracy: 9809/10000 (98.09%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.0
# Three      - 98.1
# Four       - 98.1
# Five       - 98.7
# Six        - 98.2
# Seven      - 97.2
# Eight      - 96.5
# Nine       - 97.3
#
#  | Global training round : 112/200 |
#
#
# Average test loss: 0.0582, Test accuracy: 9810/10000 (98.10%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.0
# Three      - 98.0
# Four       - 98.1
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.1
# Eight      - 96.8
# Nine       - 97.3
#
#  | Global training round : 113/200 |
#
#
# Average test loss: 0.0586, Test accuracy: 9810/10000 (98.10%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.0
# Three      - 98.1
# Four       - 98.0
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.6
# Nine       - 97.3
#
#  | Global training round : 114/200 |
#
#
# Average test loss: 0.0575, Test accuracy: 9816/10000 (98.16%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.1
# Three      - 98.0
# Four       - 98.5
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.8
# Nine       - 97.3
#
#  | Global training round : 115/200 |
#
#
# Average test loss: 0.0569, Test accuracy: 9817/10000 (98.17%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.0
# Three      - 98.3
# Four       - 98.0
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.9
# Nine       - 97.6
#
#  | Global training round : 116/200 |
#
#
# Average test loss: 0.0577, Test accuracy: 9816/10000 (98.16%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.1
# Three      - 98.2
# Four       - 97.8
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.3
# Eight      - 96.8
# Nine       - 97.6
#
#  | Global training round : 117/200 |
#
#
# Average test loss: 0.0570, Test accuracy: 9818/10000 (98.18%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.2
# Three      - 98.2
# Four       - 98.1
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.3
# Eight      - 96.7
# Nine       - 97.5
#
#  | Global training round : 118/200 |
#
#
# Average test loss: 0.0574, Test accuracy: 9823/10000 (98.23%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.1
# Three      - 98.1
# Four       - 98.4
# Five       - 98.7
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.8
# Nine       - 97.6
#
#  | Global training round : 119/200 |
#
#
# Average test loss: 0.0566, Test accuracy: 9819/10000 (98.19%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.3
# Two        - 98.0
# Three      - 98.1
# Four       - 98.1
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 120/200 |
#
#
# Average test loss: 0.0565, Test accuracy: 9818/10000 (98.18%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.3
# Four       - 98.1
# Five       - 98.4
# Six        - 98.5
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 97.5
#
#  | Global training round : 121/200 |
#
#
# Average test loss: 0.0560, Test accuracy: 9823/10000 (98.23%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.1
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.3
# Eight      - 96.7
# Nine       - 97.5
#
#  | Global training round : 122/200 |
#
#
# Average test loss: 0.0558, Test accuracy: 9820/10000 (98.20%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.1
# Three      - 98.4
# Four       - 98.3
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 97.4
#
#  | Global training round : 123/200 |
#
#
# Average test loss: 0.0563, Test accuracy: 9818/10000 (98.18%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.1
# Three      - 98.1
# Four       - 98.4
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.2
# Eight      - 97.0
# Nine       - 97.2
#
#  | Global training round : 124/200 |
#
#
# Average test loss: 0.0552, Test accuracy: 9826/10000 (98.26%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.2
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 125/200 |
#
#
# Average test loss: 0.0554, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.1
# Four       - 98.4
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.3
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 126/200 |
#
#
# Average test loss: 0.0556, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.1
# Three      - 98.3
# Four       - 98.3
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.3
# Eight      - 96.8
# Nine       - 97.6
#
#  | Global training round : 127/200 |
#
#
# Average test loss: 0.0549, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.2
# Three      - 98.5
# Four       - 98.7
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 128/200 |
#
#
# Average test loss: 0.0553, Test accuracy: 9829/10000 (98.29%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.4
# Three      - 98.3
# Four       - 98.2
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.0
# Nine       - 97.7
#
#  | Global training round : 129/200 |
#
#
# Average test loss: 0.0551, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.1
# Four       - 98.6
# Five       - 98.7
# Six        - 98.4
# Seven      - 97.4
# Eight      - 96.8
# Nine       - 97.5
#
#  | Global training round : 130/200 |
#
#
# Average test loss: 0.0554, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.3
# Three      - 98.3
# Four       - 98.3
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.4
# Eight      - 96.6
# Nine       - 97.6
#
#  | Global training round : 131/200 |
#
#
# Average test loss: 0.0554, Test accuracy: 9823/10000 (98.23%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.4
# Eight      - 96.7
# Nine       - 97.4
#
#  | Global training round : 132/200 |
#
#
# Average test loss: 0.0549, Test accuracy: 9829/10000 (98.29%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.3
# Three      - 98.3
# Four       - 98.6
# Five       - 98.5
# Six        - 98.4
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 133/200 |
#
#
# Average test loss: 0.0545, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 134/200 |
#
#
# Average test loss: 0.0547, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.2
# Three      - 98.4
# Four       - 98.3
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.4
# Eight      - 96.9
# Nine       - 97.5
#
#  | Global training round : 135/200 |
#
#
# Average test loss: 0.0543, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.3
# Three      - 98.3
# Four       - 98.1
# Five       - 98.7
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.8
#
#  | Global training round : 136/200 |
#
#
# Average test loss: 0.0544, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.3
# Three      - 98.2
# Four       - 98.3
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.5
# Eight      - 96.6
# Nine       - 97.4
#
#  | Global training round : 137/200 |
#
#
# Average test loss: 0.0535, Test accuracy: 9831/10000 (98.31%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.3
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.1
# Nine       - 97.6
#
#  | Global training round : 138/200 |
#
#
# Average test loss: 0.0540, Test accuracy: 9826/10000 (98.26%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.2
# Three      - 98.1
# Four       - 98.4
# Five       - 98.7
# Six        - 98.5
# Seven      - 97.4
# Eight      - 96.9
# Nine       - 97.5
#
#  | Global training round : 139/200 |
#
#
# Average test loss: 0.0536, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.4
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.0
# Nine       - 97.6
#
#  | Global training round : 140/200 |
#
#
# Average test loss: 0.0532, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.4
# Three      - 98.2
# Four       - 98.5
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.0
# Nine       - 97.4
#
#  | Global training round : 141/200 |
#
#
# Average test loss: 0.0529, Test accuracy: 9831/10000 (98.31%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.4
# Three      - 98.2
# Four       - 98.6
# Five       - 98.5
# Six        - 98.5
# Seven      - 97.5
# Eight      - 97.0
# Nine       - 97.4
#
#  | Global training round : 142/200 |
#
#
# Average test loss: 0.0527, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.2
# Three      - 98.3
# Four       - 98.7
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.6
# Eight      - 97.1
# Nine       - 97.4
#
#  | Global training round : 143/200 |
#
#
# Average test loss: 0.0523, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.3
# Three      - 98.5
# Four       - 98.2
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 144/200 |
#
#
# Average test loss: 0.0534, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.4
# Three      - 98.4
# Four       - 98.4
# Five       - 98.4
# Six        - 98.5
# Seven      - 97.4
# Eight      - 96.6
# Nine       - 97.4
#
#  | Global training round : 145/200 |
#
#
# Average test loss: 0.0523, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.2
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.6
# Eight      - 96.9
# Nine       - 97.5
#
#  | Global training round : 146/200 |
#
#
# Average test loss: 0.0522, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.3
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.5
# Eight      - 97.1
# Nine       - 97.6
#
#  | Global training round : 147/200 |
#
#
# Average test loss: 0.0526, Test accuracy: 9830/10000 (98.30%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.2
# Three      - 98.4
# Four       - 98.4
# Five       - 98.4
# Six        - 98.6
# Seven      - 97.5
# Eight      - 96.8
# Nine       - 97.5
#
#  | Global training round : 148/200 |
#
#
# Average test loss: 0.0520, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.2
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.6
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 149/200 |
#
#
# Average test loss: 0.0521, Test accuracy: 9841/10000 (98.41%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.3
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.2
# Nine       - 97.7
#
#  | Global training round : 150/200 |
#
#
# Average test loss: 0.0524, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.2
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.6
# Eight      - 96.9
# Nine       - 97.6
#
#  | Global training round : 151/200 |
#
#
# Average test loss: 0.0520, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.3
# Three      - 98.3
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 96.9
# Nine       - 97.6
#
#  | Global training round : 152/200 |
#
#
# Average test loss: 0.0520, Test accuracy: 9837/10000 (98.37%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.9
# Seven      - 97.6
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 153/200 |
#
#
# Average test loss: 0.0514, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.3
# Three      - 98.4
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 97.4
# Nine       - 97.7
#
#  | Global training round : 154/200 |
#
#
# Average test loss: 0.0524, Test accuracy: 9838/10000 (98.38%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.4
# Three      - 98.4
# Four       - 98.5
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.7
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 155/200 |
#
#
# Average test loss: 0.0516, Test accuracy: 9837/10000 (98.37%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.3
# Three      - 98.5
# Four       - 98.3
# Five       - 98.5
# Six        - 98.6
# Seven      - 97.7
# Eight      - 97.1
# Nine       - 97.6
#
#  | Global training round : 156/200 |
#
#
# Average test loss: 0.0522, Test accuracy: 9836/10000 (98.36%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.2
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# ...
# Seven      - 97.6
# Eight      - 97.3
# Nine       - 97.6
#
#  | Global training round : 171/200 |
#
#
# Average test loss: 0.0496, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.3
# Nine       - 97.7
#
#  | Global training round : 172/200 |
#
#
# Average test loss: 0.0502, Test accuracy: 9841/10000 (98.41%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.8
# Eight      - 97.0
# Nine       - 97.3
#
#  | Global training round : 173/200 |
#
#
# Average test loss: 0.0494, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.4
# Nine       - 97.5
#
#  | Global training round : 174/200 |
#
#
# Average test loss: 0.0493, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.8
# Eight      - 97.0
# Nine       - 97.6
#
#  | Global training round : 175/200 |
#
#
# Average test loss: 0.0496, Test accuracy: 9843/10000 (98.43%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.3
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.3
# Nine       - 97.4
#
#  | Global training round : 176/200 |
#
#
# Average test loss: 0.0496, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.8
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.0
# Nine       - 97.6
#
#  | Global training round : 177/200 |
#
#
# Average test loss: 0.0496, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.9
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.4
#
#  | Global training round : 178/200 |
#
#
# Average test loss: 0.0499, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.4
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.2
# Nine       - 97.6
#
#  | Global training round : 179/200 |
#
#
# Average test loss: 0.0495, Test accuracy: 9843/10000 (98.43%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.0
# Nine       - 97.6
#
#  | Global training round : 180/200 |
#
#
# Average test loss: 0.0490, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.3
# Nine       - 97.6
#
#  | Global training round : 181/200 |
#
#
# Average test loss: 0.0492, Test accuracy: 9846/10000 (98.46%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.6
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.6
# Eight      - 97.0
# Nine       - 97.6
#
#  | Global training round : 182/200 |
#
#
# Average test loss: 0.0493, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.4
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.1
# Nine       - 97.3
#
#  | Global training round : 183/200 |
#
#
# Average test loss: 0.0493, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 96.9
# Nine       - 97.7
#
#  | Global training round : 184/200 |
#
#
# Average test loss: 0.0493, Test accuracy: 9845/10000 (98.45%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.5
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 96.9
# Nine       - 97.6
#
#  | Global training round : 185/200 |
#
#
# Average test loss: 0.0489, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.8
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.0
# Nine       - 97.8
#
#  | Global training round : 186/200 |
#
#
# Average test loss: 0.0498, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.6
# Three      - 98.4
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 96.8
# Nine       - 97.6
#
#  | Global training round : 187/200 |
#
#
# Average test loss: 0.0479, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.6
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.7
# Eight      - 97.3
# Nine       - 97.8
#
#  | Global training round : 188/200 |
#
#
# Average test loss: 0.0490, Test accuracy: 9851/10000 (98.51%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.5
# Two        - 98.6
# Three      - 98.5
# Four       - 98.6
# Five       - 98.7
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.2
# Nine       - 97.6
#
#  | Global training round : 189/200 |
#
#
# Average test loss: 0.0485, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.6
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.2
# Nine       - 97.7
#
#  | Global training round : 190/200 |
#
#
# Average test loss: 0.0481, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.6
# Four       - 98.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.7
# Eight      - 96.9
# Nine       - 97.7
#
#  | Global training round : 191/200 |
#
#
# Average test loss: 0.0481, Test accuracy: 9852/10000 (98.52%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.9
# Seven      - 97.6
# Eight      - 97.4
# Nine       - 97.7
#
#  | Global training round : 192/200 |
#
#
# Average test loss: 0.0482, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.0
# Nine       - 97.7
#
#  | Global training round : 193/200 |
#
#
# Average test loss: 0.0482, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.6
# Three      - 98.4
# Four       - 98.7
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.1
# Nine       - 97.6
#
#  | Global training round : 194/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.8
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.8
# Eight      - 97.0
# Nine       - 97.5
#
#  | Global training round : 195/200 |
#
#
# Average test loss: 0.0484, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.9
# Eight      - 97.2
# Nine       - 97.7
#
#  | Global training round : 196/200 |
#
#
# Average test loss: 0.0481, Test accuracy: 9847/10000 (98.47%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 98.4
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.0
# Nine       - 97.7
#
#  | Global training round : 197/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.6
# One        - 99.6
# Two        - 98.7
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.0
# Nine       - 97.7
#
#  | Global training round : 198/200 |
#
#
# Average test loss: 0.0481, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.5
# Four       - 98.5
# Five       - 98.5
# Six        - 98.9
# Seven      - 98.0
# Eight      - 97.1
# Nine       - 97.5
#
#  | Global training round : 199/200 |
#
#
# Average test loss: 0.0480, Test accuracy: 9850/10000 (98.50%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.5
# Four       - 98.4
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.1
# Nine       - 97.7
#
#  | Global training round : 200/200 |
#
#
# Average test loss: 0.0472, Test accuracy: 9849/10000 (98.49%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.5
# Four       - 98.7
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.0
# Nine       - 97.4
# Last 10 updates results
#
# Average test loss: 0.0479, Test accuracy: 9851/10000 (98.51%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.8
# Three      - 98.5
# Four       - 98.6
# Five       - 98.5
# Six        - 98.7
# Seven      - 98.0
# Eight      - 97.1
# Nine       - 97.7
# Global accuracies:  [25.54, 46.88, 64.06, 80.07, 87.01, 90.19, 91.82, 92.2, 92.96, 93.79, 94.19, 94.41, 94.74, 95.08, 95.28, 95.34, 95.66, 95.75, 95.86, 95.96, 96.06, 96.16, 96.31, 96.37, 96.38, 96.5, 96.55, 96.59, 96.72, 96.74, 96.81, 96.84, 96.96, 96.97, 96.97, 97.08, 97.07, 97.1, 97.16, 97.17, 97.19, 97.19, 97.28, 97.26, 97.32, 97.35, 97.42, 97.4, 97.43, 97.48, 97.47, 97.47, 97.46, 97.48, 97.56, 97.54, 97.54, 97.59, 97.6, 97.64, 97.65, 97.61, 97.65, 97.64, 97.63, 97.69, 97.72, 97.68, 97.7, 97.76, 97.75, 97.8, 97.75, 97.8, 97.79, 97.82, 97.84, 97.84, 97.84, 97.88, 97.92, 97.87, 97.91, 97.92, 97.88, 97.89, 97.93, 97.95, 97.9, 97.99, 97.91, 97.92, 98.0, 97.98, 97.99, 97.96, 98.0, 98.02, 98.07, 98.01, 98.01, 98.0, 97.98, 98.02, 98.01, 98.04, 98.08, 98.1, 98.12, 98.09, 98.09, 98.1, 98.1, 98.16, 98.17, 98.16, 98.18, 98.23, 98.19, 98.18, 98.23, 98.2, 98.18, 98.26, 98.25, 98.24, 98.33, 98.29, 98.27, 98.24, 98.23, 98.29, 98.3, 98.24, 98.3, 98.24, 98.31, 98.26, 98.3, 98.3, 98.31, 98.35, 98.33, 98.27, 98.33, 98.33, 98.3, 98.35, 98.41, 98.35, 98.35, 98.37, 98.4, 98.38, 98.37, 98.36, 98.39, 98.37, 98.43, 98.44, 98.43, 98.4, 98.39, 98.38, 98.43, 98.43, 98.4, 98.41, 98.45, 98.49, 98.48, 98.41, 98.47, 98.42, 98.43, 98.46, 98.47, 98.46, 98.43, 98.5, 98.46, 98.42, 98.45, 98.45, 98.47, 98.42, 98.5, 98.51, 98.48, 98.48, 98.52, 98.48, 98.48, 98.47, 98.5, 98.47, 98.5, 98.48, 98.5, 98.49, 98.51]
# Class 7 accuracies:  [87.26, 88.33, 87.65, 85.41, 85.6, 86.48, 89.49, 90.76, 91.44, 92.41, 92.8, 93.48, 93.09, 94.16, 94.16, 94.07, 94.26, 94.26, 94.16, 94.36, 94.65, 94.36, 95.14, 94.84, 94.84, 95.14, 95.04, 95.33, 95.43, 95.33, 95.53, 95.53, 95.62, 95.82, 95.72, 95.72, 95.72, 95.82, 96.01, 95.91, 95.72, 96.11, 96.21, 96.01, 95.91, 96.21, 96.11, 96.01, 96.11, 96.21, 96.21, 96.11, 96.21, 96.3, 96.3, 96.4, 96.3, 96.3, 96.3, 96.3, 96.21, 96.3, 96.3, 96.4, 96.3, 96.3, 96.3, 96.69, 96.3, 96.5, 96.5, 96.6, 96.5, 96.69, 96.5, 96.69, 96.79, 96.69, 96.69, 96.79, 96.69, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.79, 96.89, 96.98, 96.89, 97.08, 96.98, 97.08, 96.98, 96.98, 96.98, 96.98, 97.08, 97.18, 97.18, 97.08, 97.18, 97.18, 97.08, 97.18, 97.18, 97.18, 97.28, 97.28, 97.18, 97.28, 97.18, 97.28, 97.18, 97.18, 97.28, 97.28, 97.28, 97.28, 97.28, 97.37, 97.37, 97.37, 97.37, 97.37, 97.37, 97.37, 97.47, 97.37, 97.37, 97.28, 97.37, 97.47, 97.57, 97.57, 97.37, 97.57, 97.47, 97.47, 97.57, 97.57, 97.57, 97.57, 97.57, 97.47, 97.67, 97.67, 97.57, 97.57, 97.67, 97.67, 97.67, 97.76, 97.57, 97.67, 97.57, 97.76, 97.67, 97.67, 97.57, 97.57, 97.57, 97.67, 97.76, 97.67, 97.76, 97.57, 97.67, 97.67, 97.67, 97.86, 97.96, 97.57, 97.86, 97.86, 97.96, 97.67, 97.96, 97.67, 97.96, 97.96, 97.67, 97.57, 97.86, 97.96, 97.76, 97.86, 97.96, 97.96, 97.96, 97.96, 97.96, 97.96]
# trust Weightes : {0: 0.022522976122267797, 1: 0.019158778047444945, 2: 0.0, 3: 0.01870349812055225, 4: 0.0, 5: 0.012281887301423265, 6: 0.014247721079246, 7: 0.010300754128627652, 8: 0.0, 9: 0.02199058688847163, 10: 0.020738536398747235, 11: 0.0, 12: 0.0, 13: 0.0, 14: 0.021587793831437083, 15: 0.018815605411358856, 16: 0.0, 17: 0.0, 18: 0.01181438296554565, 19: 0.01487853345976877, 20: 0.0, 21: 0.0, 22: 0.0, 23: 0.0, 24: 0.0, 25: 0.0, 26: 0.017418211402082877, 27: 0.022283536075646197, 28: 0.0, 29: 0.0, 30: 0.008996173594664052, 31: 0.02346276650511092, 32: 0.0, 33: 0.013631627556206187, 34: 0.0, 35: 0.0, 36: 0.01561730214555588, 37: 0.0, 38: 0.01476024729610998, 39: 0.009137411562969426, 40: 0.006368731993457457, 41: 0.0007205237550823661, 42: 0.02083946956106951, 43: 0.0, 44: 0.019270813623018204, 45: 0.013291964375888497, 46: 0.0, 47: 0.029095999930867686, 48: 0.01532146612245417, 49: 0.02657297774448645, 50: 0.011653314220311227, 51: 0.025384632070512687, 52: 0.00992400590362553, 53: 0.01887257335579804, 54: 0.009178912201527908, 55: 0.0, 56: 0.011578063226647626, 57: 0.0, 58: 0.01793265801262743, 59: 0.02379343040114502, 60: 0.0, 61: 0.01797454743734188, 62: 0.0, 63: 0.018319618248751935, 64: 0.014375562363664484, 65: 0.022364012435779405, 66: 0.021239625421863872, 67: 0.0070560224135471465, 68: 0.02272467129530312, 69: 0.01911193109132769, 70: 0.026096262048168006, 71: 0.0260168227099162, 72: 0.012199165525364469, 73: 0.0, 74: 0.023032696782025946, 75: 0.0, 76: 0.016125082989814063, 77: 0.0, 78: 0.014222331777907226, 79: 0.014686989684209029, 80: 0.0, 81: 0.007461282678313038, 82: 0.0, 83: 0.011925173105487437, 84: 0.022146264784606323, 85: 0.0067907996082778544, 86: 0.019255254627612576, 87: 0.0, 88: 0.023009859205161277, 89: 0.012036601868823901, 90: 0.0, 91: 0.0, 92: 0.0, 93: 0.0, 94: 0.01376171000483493, 95: 0.0, 96: 0.01591984550014155, 97: 0.0, 98: 0.0, 99: 0.0}
# Test loss: [2.2252, 1.9601, 1.482, 1.1112, 0.8528, 0.611, 0.4237, 0.302, 0.2571, 0.2283, 0.209, 0.1944, 0.1821, 0.1717, 0.164, 0.156, 0.1493, 0.1433, 0.138, 0.1343, 0.1295, 0.1259, 0.1225, 0.1194, 0.1163, 0.1122, 0.1119, 0.1087, 0.1074, 0.1049, 0.1022, 0.102, 0.0992, 0.0983, 0.096, 0.0948, 0.0933, 0.0921, 0.0921, 0.0907, 0.0892, 0.0891, 0.0865, 0.0861, 0.0851, 0.0835, 0.0831, 0.0834, 0.0815, 0.0806, 0.0807, 0.0799, 0.0794, 0.0786, 0.077, 0.0778, 0.0766, 0.076, 0.0758, 0.0745, 0.0743, 0.074, 0.0733, 0.0734, 0.0724, 0.0719, 0.0708, 0.0709, 0.071, 0.0693, 0.0691, 0.0688, 0.0687, 0.0682, 0.0682, 0.067, 0.0674, 0.0668, 0.0663, 0.0662, 0.0654, 0.0665, 0.0652, 0.0649, 0.0651, 0.0642, 0.0645, 0.0633, 0.0638, 0.0631, 0.0628, 0.0632, 0.0622, 0.0618, 0.0616, 0.0612, 0.0614, 0.061, 0.0612, 0.0608, 0.0605, 0.0604, 0.0603, 0.0599, 0.06, 0.0598, 0.0596, 0.0591, 0.0587, 0.0583, 0.0585, 0.0582, 0.0586, 0.0575, 0.0569, 0.0577, 0.057, 0.0574, 0.0566, 0.0565, 0.056, 0.0558, 0.0563, 0.0552, 0.0554, 0.0556, 0.0549, 0.0553, 0.0551, 0.0554, 0.0554, 0.0549, 0.0545, 0.0547, 0.0543, 0.0544, 0.0535, 0.054, 0.0536, 0.0532, 0.0529, 0.0527, 0.0523, 0.0534, 0.0523, 0.0522, 0.0526, 0.052, 0.0521, 0.0524, 0.052, 0.052, 0.0514, 0.0524, 0.0516, 0.0522, 0.0516, 0.0516, 0.0514, 0.0511, 0.0509, 0.0505, 0.0509, 0.051, 0.0501, 0.0496, 0.0497, 0.0499, 0.0495, 0.0497, 0.0496, 0.0502, 0.0494, 0.0493, 0.0496, 0.0496, 0.0496, 0.0499, 0.0495, 0.049, 0.0492, 0.0493, 0.0493, 0.0493, 0.0489, 0.0498, 0.0479, 0.049, 0.0485, 0.0481, 0.0481, 0.0482, 0.0482, 0.048, 0.0484, 0.0481, 0.048, 0.0481, 0.048, 0.0472, 0.0479]
# Attack succes rate: 0.19
# Average CPU aggregation runtime: 0.0030577635765075685
#
# --> End of Experiment.
